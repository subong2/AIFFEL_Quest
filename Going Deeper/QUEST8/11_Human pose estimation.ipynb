# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 앞으로 사용할 라이브러리를 불러옵니다. 고정해서 사용할 변수도 만들어 두죠.

# %%
import io, json, os, math

import tensorflow as tf
from tensorflow.keras.layers import Add, Concatenate, Lambda
from tensorflow.keras.layers import Input, Conv2D, ReLU, MaxPool2D
from tensorflow.keras.layers import UpSampling2D, ZeroPadding2D
from tensorflow.keras.layers import BatchNormalization
import ray

import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

PROJECT_PATH = os.getenv('HOME') + '/aiffel/mpii'
IMAGE_PATH = os.path.join(PROJECT_PATH, 'images')
MODEL_PATH = os.path.join(PROJECT_PATH, 'models')
TFRECORD_PATH = os.path.join(PROJECT_PATH, 'tfrecords_mpii')
TRAIN_JSON = os.path.join(PROJECT_PATH, 'mpii_human_pose_v1_u12_2', 'train.json')
VALID_JSON = os.path.join(PROJECT_PATH, 'mpii_human_pose_v1_u12_2', 'validation.json')

# %%
# json annotation 을 파싱하는 함수

# %%
def parse_one_annotation(anno, image_dir):
    filename = anno['image']
    joints = anno['joints']
    joints_visibility = anno['joints_vis']
    annotation = {
        'filename': filename,
        'filepath': os.path.join(image_dir, filename),
        'joints_visibility': joints_visibility,
        'joints': joints,
        'center': anno['center'],
        'scale' : anno['scale']
    }
    return annotation

# %%
# TFRecord 파일 만들기

# %%
def generate_tfexample(anno):

    # byte 인코딩을 위한 함수
    def _bytes_feature(value):
        if isinstance(value, type(tf.constant(0))):
            value = value.numpy()
        return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))

    filename = anno['filename']
    filepath = anno['filepath']
    with open(filepath, 'rb') as image_file:
        content = image_file.read()

    image = Image.open(filepath)
    if image.format != 'JPEG' or image.mode != 'RGB':
        image_rgb = image.convert('RGB')
        with io.BytesIO() as output:
            image_rgb.save(output, format="JPEG", quality=95)
            content = output.getvalue()

    width, height = image.size
    depth = 3

    c_x = int(anno['center'][0])
    c_y = int(anno['center'][1])
    scale = anno['scale']

    x = [
        int(joint[0]) if joint[0] >= 0 else int(joint[0]) 
        for joint in anno['joints']
    ]
    y = [
        int(joint[1]) if joint[1] >= 0 else int(joint[0]) 
        for joint in anno['joints']
    ]

    v = [0 if joint_v == 0 else 2 for joint_v in anno['joints_visibility']]

    feature = {
        'image/height':
        tf.train.Feature(int64_list=tf.train.Int64List(value=[height])),
        'image/width':
        tf.train.Feature(int64_list=tf.train.Int64List(value=[width])),
        'image/depth':
        tf.train.Feature(int64_list=tf.train.Int64List(value=[depth])),
        'image/object/parts/x':
        tf.train.Feature(int64_list=tf.train.Int64List(value=x)),
        'image/object/parts/y':
        tf.train.Feature(int64_list=tf.train.Int64List(value=y)),
        'image/object/center/x': 
        tf.train.Feature(int64_list=tf.train.Int64List(value=[c_x])),
        'image/object/center/y': 
        tf.train.Feature(int64_list=tf.train.Int64List(value=[c_y])),
        'image/object/scale':
        tf.train.Feature(float_list=tf.train.FloatList(value=[scale])),
        'image/object/parts/v':
        tf.train.Feature(int64_list=tf.train.Int64List(value=v)),
        'image/encoded':
        _bytes_feature(content),
        'image/filename':
        _bytes_feature(filename.encode())
    }

    return tf.train.Example(features=tf.train.Features(feature=feature))

# %%
# 얼마나 많은 TFRecord를 만들지 결정할 함수 만들기

# %%
def chunkify(l, n):
    size = len(l) // n
    start = 0
    results = []
    for i in range(n):
        results.append(l[start:start + size])
        start += size
    return results

# %%
# chunk를 TFRecord로 만들어 줄 함수

# %%
@ray.remote
def build_single_tfrecord(chunk, path):
    print('start to build tf records for ' + path)

    with tf.io.TFRecordWriter(path) as writer:
        for anno in chunk:
            tf_example = generate_tfexample(anno)
            writer.write(tf_example.SerializeToString())

    print('finished building tf records for ' + path)

# %%
# 전체 데이터를 적당한 수의 TFRecord 파일로 만들어주는 함수를 만듭시다. ray를 사용

# %%
def build_tf_records(annotations, total_shards, split):
    chunks = chunkify(annotations, total_shards)
    futures = [
        build_single_tfrecord.remote(
            chunk, '{}/{}_{}_of_{}.tfrecords'.format(
                TFRECORD_PATH,
                split,
                str(i + 1).zfill(4),
                str(total_shards).zfill(4),
            )) for i, chunk in enumerate(chunks)
    ]
    ray.get(futures)

# %%
# 앞서 작성한 함수를 사용해 데이터를 TFRecord로 만들어 줍니다. train 데이터는 64개로, val 데이터는 8개의 파일로 만들기

# %%
# Ray

num_train_shards = 64
num_val_shards = 8

# ray.init()

# print('Start to parse annotations.')
# if not os.path.exists(TFRECORD_PATH):
#     os.makedirs(TFRECORD_PATH)

# with open(TRAIN_JSON) as train_json:
#     train_annos = json.load(train_json)
#     train_annotations = [
#         parse_one_annotation(anno, IMAGE_PATH)
#         for anno in train_annos
#     ]
#     print('First train annotation: ', train_annotations[0])

# with open(VALID_JSON) as val_json:
#     val_annos = json.load(val_json)
#     val_annotations = [
#         parse_one_annotation(anno, IMAGE_PATH) 
#         for anno in val_annos
#     ]
#     print('First val annotation: ', val_annotations[0])
    
# print('Start to build TF Records.')
# build_tf_records(train_annotations, num_train_shards, 'train')
# build_tf_records(val_annotations, num_val_shards, 'val')

# print('Successfully wrote {} annotations to TF Records.'.format(
#     len(train_annotations) + len(val_annotations)))

# %%
# data label 로 만들기
# TFRecord로 저장된 데이터를 모델 학습에 필요한 데이터로 바꿔줄 함수
# image 와 label 을 이용해서 적절한 학습 형태로 변환
# 적당히 정사각형으로 crop

# %%
class Preprocessor(object):
    def __init__(self,
                 image_shape=(256, 256, 3),
                 heatmap_shape=(64, 64, 16),
                 is_train=False):
        self.is_train = is_train
        self.image_shape = image_shape
        self.heatmap_shape = heatmap_shape

    def __call__(self, example):
        features = self.parse_tfexample(example)
        image = tf.io.decode_jpeg(features['image/encoded'])

        if self.is_train:
            random_margin = tf.random.uniform([1], 0.1, 0.3)[0]
            image, keypoint_x, keypoint_y = self.crop_roi(image, features, margin=random_margin)
            image = tf.image.resize(image, self.image_shape[0:2])
        else:
            image, keypoint_x, keypoint_y = self.crop_roi(image, features)
            image = tf.image.resize(image, self.image_shape[0:2])

        image = tf.cast(image, tf.float32) / 127.5 - 1
        heatmaps = self.make_heatmaps(features, keypoint_x, keypoint_y, self.heatmap_shape)

        return image, heatmaps

        
    def crop_roi(self, image, features, margin=0.2):
        img_shape = tf.shape(image)
        img_height = img_shape[0]
        img_width = img_shape[1]
        img_depth = img_shape[2]

        keypoint_x = tf.cast(tf.sparse.to_dense(features['image/object/parts/x']), dtype=tf.int32)
        keypoint_y = tf.cast(tf.sparse.to_dense(features['image/object/parts/y']), dtype=tf.int32)
        center_x = features['image/object/center/x']
        center_y = features['image/object/center/y']
        body_height = features['image/object/scale'] * 200.0
        
        masked_keypoint_x = tf.boolean_mask(keypoint_x, keypoint_x > 0)
        masked_keypoint_y = tf.boolean_mask(keypoint_y, keypoint_y > 0)
        
        keypoint_xmin = tf.reduce_min(masked_keypoint_x)
        keypoint_xmax = tf.reduce_max(masked_keypoint_x)
        keypoint_ymin = tf.reduce_min(masked_keypoint_y)
        keypoint_ymax = tf.reduce_max(masked_keypoint_y)
        
        xmin = keypoint_xmin - tf.cast(body_height * margin, dtype=tf.int32)
        xmax = keypoint_xmax + tf.cast(body_height * margin, dtype=tf.int32)
        ymin = keypoint_ymin - tf.cast(body_height * margin, dtype=tf.int32)
        ymax = keypoint_ymax + tf.cast(body_height * margin, dtype=tf.int32)
        
        effective_xmin = xmin if xmin > 0 else 0
        effective_ymin = ymin if ymin > 0 else 0
        effective_xmax = xmax if xmax < img_width else img_width
        effective_ymax = ymax if ymax < img_height else img_height
        effective_height = effective_ymax - effective_ymin
        effective_width = effective_xmax - effective_xmin

        image = image[effective_ymin:effective_ymax, effective_xmin:effective_xmax, :]
        new_shape = tf.shape(image)
        new_height = new_shape[0]
        new_width = new_shape[1]
        
        effective_keypoint_x = (keypoint_x - effective_xmin) / new_width
        effective_keypoint_y = (keypoint_y - effective_ymin) / new_height
        
        return image, effective_keypoint_x, effective_keypoint_y
        
    
    def generate_2d_guassian(self, height, width, y0, x0, visibility=2, sigma=1, scale=12):
        
        heatmap = tf.zeros((height, width))

        xmin = x0 - 3 * sigma
        ymin = y0 - 3 * sigma
        xmax = x0 + 3 * sigma
        ymax = y0 + 3 * sigma

        if xmin >= width or ymin >= height or xmax < 0 or ymax <0 or visibility == 0:
            return heatmap

        size = 6 * sigma + 1
        x, y = tf.meshgrid(tf.range(0, 6*sigma+1, 1), tf.range(0, 6*sigma+1, 1), indexing='xy')

        center_x = size // 2
        center_y = size // 2

        gaussian_patch = tf.cast(tf.math.exp(-(tf.square(x - center_x) + tf.math.square(y - center_y)) / (tf.math.square(sigma) * 2)) * scale, dtype=tf.float32)

        patch_xmin = tf.math.maximum(0, -xmin)
        patch_ymin = tf.math.maximum(0, -ymin)
        patch_xmax = tf.math.minimum(xmax, width) - xmin
        patch_ymax = tf.math.minimum(ymax, height) - ymin

        heatmap_xmin = tf.math.maximum(0, xmin)
        heatmap_ymin = tf.math.maximum(0, ymin)
        heatmap_xmax = tf.math.minimum(xmax, width)
        heatmap_ymax = tf.math.minimum(ymax, height)

        indices = tf.TensorArray(tf.int32, 1, dynamic_size=True)
        updates = tf.TensorArray(tf.float32, 1, dynamic_size=True)

        count = 0

        for j in tf.range(patch_ymin, patch_ymax):
            for i in tf.range(patch_xmin, patch_xmax):
                indices = indices.write(count, [heatmap_ymin+j, heatmap_xmin+i])
                updates = updates.write(count, gaussian_patch[j][i])
                count += 1
                
        heatmap = tf.tensor_scatter_nd_update(heatmap, indices.stack(), updates.stack())

        return heatmap


    def make_heatmaps(self, features, keypoint_x, keypoint_y, heatmap_shape):
        v = tf.cast(tf.sparse.to_dense(features['image/object/parts/v']), dtype=tf.float32)
        x = tf.cast(tf.math.round(keypoint_x * heatmap_shape[0]), dtype=tf.int32)
        y = tf.cast(tf.math.round(keypoint_y * heatmap_shape[1]), dtype=tf.int32)
        
        num_heatmap = heatmap_shape[2]
        heatmap_array = tf.TensorArray(tf.float32, 16)

        for i in range(num_heatmap):
            gaussian = self.generate_2d_guassian(heatmap_shape[1], heatmap_shape[0], y[i], x[i], v[i])
            heatmap_array = heatmap_array.write(i, gaussian)
        
        heatmaps = heatmap_array.stack()
        heatmaps = tf.transpose(heatmaps, perm=[1, 2, 0]) # change to (64, 64, 16)
        
        return heatmaps

    def parse_tfexample(self, example):
        image_feature_description = {
            'image/height': tf.io.FixedLenFeature([], tf.int64),
            'image/width': tf.io.FixedLenFeature([], tf.int64),
            'image/depth': tf.io.FixedLenFeature([], tf.int64),
            'image/object/parts/x': tf.io.VarLenFeature(tf.int64),
            'image/object/parts/y': tf.io.VarLenFeature(tf.int64),
            'image/object/parts/v': tf.io.VarLenFeature(tf.int64),
            'image/object/center/x': tf.io.FixedLenFeature([], tf.int64),
            'image/object/center/y': tf.io.FixedLenFeature([], tf.int64),
            'image/object/scale': tf.io.FixedLenFeature([], tf.float32),
            'image/encoded': tf.io.FixedLenFeature([], tf.string),
            'image/filename': tf.io.FixedLenFeature([], tf.string),
        }
        return tf.io.parse_single_example(example,
                                          image_feature_description)

# %%
# simplebaseline

# %%
import os

import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

resnet = tf.keras.applications.resnet.ResNet50(include_top=False, weights='imagenet')

# %%
def _make_deconv_layer(num_deconv_layers):
    seq_model = tf.keras.models.Sequential()
    for i in range(num_deconv_layers):
        seq_model.add(tf.keras.layers.Conv2DTranspose(256, kernel_size=(4,4), strides=(2,2), padding='same'))
        seq_model.add(tf.keras.layers.BatchNormalization())
        seq_model.add(tf.keras.layers.ReLU())
    return seq_model

upconv = _make_deconv_layer(3)

# %%
final_layer = tf.keras.layers.Conv2D(16, kernel_size=(1,1), padding='same')

# %%
inputs = keras.Input(shape=(256, 256, 3))
x = resnet(inputs)
x = upconv(x)
out = final_layer(x)
simplebaseline_model = keras.Model(inputs, out)

simplebaseline_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# resnet50 (Functional)        (None, None, None, 2048)  23587712
# _________________________________________________________________
# sequential (Sequential)      (None, 64, 64, 256)       10489600
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 16)        4112
# =================================================================
# Total params: 34,081,424
# Trainable params: 34,026,768
# Non-trainable params: 54,656
# _________________________________________________________________

# %%
# 학습

# %%
class Trainer(object):
    def __init__(self,
                 model,
                 epochs,
                 global_batch_size,
                 strategy,
                 initial_learning_rate):
        
        self.model = model
        self.epochs = epochs
        self.strategy = strategy
        self.global_batch_size = global_batch_size
    
        self.loss_object = tf.keras.losses.MeanSquaredError(
            reduction=tf.keras.losses.Reduction.NONE)
        self.optimizer = tf.keras.optimizers.Adam(
            learning_rate=initial_learning_rate)

        self.current_learning_rate = initial_learning_rate
        self.last_val_loss = math.inf
        self.lowest_val_loss = math.inf
        self.patience_count = 0
        self.max_patience = 10
        self.best_model = None


    def lr_decay(self):
        if self.patience_count >= self.max_patience:
            self.current_learning_rate /= 10.0
            self.patience_count = 0
        elif self.last_val_loss == self.lowest_val_loss:
            self.patience_count = 0
        self.patience_count += 1

        self.optimizer.learning_rate = self.current_learning_rate
    
    def lr_decay_step(self, epoch):
        if epoch == 25 or epoch == 50 or epoch == 75:
            self.current_learning_rate /= 10.0
        self.optimizer.learning_rate = self.current_learning_rate
        
    def compute_loss(self, labels, outputs):
        loss = 0
        weights = tf.cast(labels > 0, dtype=tf.float32) * 81 + 1


        loss = tf.math.reduce_mean(
            tf.math.square(labels - outputs) * weights) * (
                1.0 / self.global_batch_size)

        return loss

    
#     def compute_loss(self, labels, outputs):
#             loss = 0
#             for output in outputs:
#                 weights = tf.cast(labels > 0, dtype=tf.float32) * 81 + 1
#                 loss += tf.math.reduce_mean(
#                     tf.math.square(labels - output) * weights) * (
#                         1. / self.global_batch_size)
#             return loss    
    
    

    def train_step(self, inputs):
        images, labels = inputs
        with tf.GradientTape() as tape:
            outputs = self.model(images, training=True)
            loss = self.compute_loss(labels, outputs)

        grads = tape.gradient(
            target=loss, sources=self.model.trainable_variables)
        self.optimizer.apply_gradients(
            zip(grads, self.model.trainable_variables))

        return loss

    def val_step(self, inputs):
        images, labels = inputs
        outputs = self.model(images, training=False)
        loss = self.compute_loss(labels, outputs)
        return loss
    
    def run(self, train_dist_dataset, val_dist_dataset):
        
        @tf.function
        def distributed_train_epoch(dataset):
            tf.print('Start distributed traininng...')
            total_loss = 0.0
            num_train_batches = 0.0
            for one_batch in dataset:
                per_replica_loss = self.strategy.run(
                    self.train_step, args=(one_batch, ))
                batch_loss = self.strategy.reduce(
                    tf.distribute.ReduceOp.SUM, per_replica_loss, axis=None)
                total_loss += batch_loss
                num_train_batches += 1
                tf.print('Trained batch', num_train_batches, 'batch loss',
                         batch_loss, 'epoch total loss', total_loss / num_train_batches)
            return total_loss, num_train_batches

        @tf.function
        def distributed_val_epoch(dataset):
            total_loss = 0.0
            num_val_batches = 0.0
            for one_batch in dataset:
                per_replica_loss = self.strategy.run(
                    self.val_step, args=(one_batch, ))
                num_val_batches += 1
                batch_loss = self.strategy.reduce(
                    tf.distribute.ReduceOp.SUM, per_replica_loss, axis=None)
                tf.print('Validated batch', num_val_batches, 'batch loss',
                         batch_loss)
                if not tf.math.is_nan(batch_loss):
                    # TODO: Find out why the last validation batch loss become NaN
                    total_loss += batch_loss
                else:
                    num_val_batches -= 1

            return total_loss, num_val_batches

        for epoch in range(1, self.epochs + 1):
            self.lr_decay()
            print('Start epoch {} with learning rate {}'.format(
                epoch, self.current_learning_rate))
            

            
            train_total_loss, num_train_batches = distributed_train_epoch(
                train_dist_dataset)
            train_loss = train_total_loss / num_train_batches
            print('Epoch {} train loss {}'.format(epoch, train_loss))
            
            
            val_total_loss, num_val_batches = distributed_val_epoch(
                val_dist_dataset)
            val_loss = val_total_loss / num_val_batches
            print('Epoch {} val loss {}'.format(epoch, val_loss))
            
            # save model when reach a new lowest validation loss
            if val_loss < self.lowest_val_loss:
                self.save_model(epoch, val_loss)
                self.lowest_val_loss = val_loss
            self.last_val_loss = val_loss

        return self.best_model

    def save_model(self, epoch, loss):
        #model_name = MODEL_PATH + '/model-epoch-{}-loss-{:.4f}.h5'.format(epoch, loss)
        #self.model.save_weights(model_name)
        #self.best_model = model_name
        #print("Model {} saved.".format(model_name))
        pass

# %%
IMAGE_SHAPE = (256, 256, 3)
HEATMAP_SIZE = (64, 64)

# %%
def create_dataset(tfrecords, batch_size, num_heatmap, is_train):
    preprocess = Preprocessor(
        IMAGE_SHAPE, (HEATMAP_SIZE[0], HEATMAP_SIZE[1], num_heatmap), is_train)

    dataset = tf.data.Dataset.list_files(tfrecords)
    dataset = tf.data.TFRecordDataset(dataset)
    dataset = dataset.map(
        preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE)

    if is_train:
        dataset = dataset.shuffle(batch_size)

    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    return dataset

# %%
def train(epochs, learning_rate, num_heatmap, batch_size, train_tfrecords, val_tfrecords):
    strategy = tf.distribute.get_strategy()
    global_batch_size = strategy.num_replicas_in_sync * batch_size
    train_dataset = create_dataset(
        train_tfrecords, global_batch_size, num_heatmap, is_train=True)
    val_dataset = create_dataset(
        val_tfrecords, global_batch_size, num_heatmap, is_train=False)

    if not os.path.exists(MODEL_PATH):
        os.makedirs(MODEL_PATH)

    with strategy.scope():
        train_dist_dataset = strategy.experimental_distribute_dataset(
            train_dataset)
        val_dist_dataset = strategy.experimental_distribute_dataset(
            val_dataset)
        
        model = simplebaseline_model

        trainer = Trainer(
            model,
            epochs,
            global_batch_size,
            strategy,
            initial_learning_rate=learning_rate)

        print('Start training...')
        return trainer.run(train_dist_dataset, val_dist_dataset)

# %%
train_tfrecords = os.path.join(TFRECORD_PATH, 'train*')
val_tfrecords = os.path.join(TFRECORD_PATH, 'val*')
epochs = 5
batch_size = 15
num_heatmap = 15
learning_rate = 0.0007
    

best_model_baseline_file = train(epochs, learning_rate, num_heatmap, batch_size, train_tfrecords, val_tfrecords)
# Out:
# Start training...
# Start epoch 1 with learning rate 0.0007
# Start distributed traininng...
# Trained batch 1 batch loss 0.77269578 epoch total loss 0.77269578
# Trained batch 2 batch loss 0.692454159 epoch total loss 0.73257494
# Trained batch 3 batch loss 0.585115373 epoch total loss 0.683421791
# Trained batch 4 batch loss 0.542099297 epoch total loss 0.648091137
# Trained batch 5 batch loss 0.492442966 epoch total loss 0.616961479
# Trained batch 6 batch loss 0.493243933 epoch total loss 0.596341908
# Trained batch 7 batch loss 0.496023148 epoch total loss 0.582010627
# Trained batch 8 batch loss 0.476691872 epoch total loss 0.568845749
# Trained batch 9 batch loss 0.436111599 epoch total loss 0.554097474
# Trained batch 10 batch loss 0.435157418 epoch total loss 0.542203486
# Trained batch 11 batch loss 0.438515782 epoch total loss 0.532777309
# Trained batch 12 batch loss 0.440971375 epoch total loss 0.525126815
# Trained batch 13 batch loss 0.40093562 epoch total loss 0.515573621
# Trained batch 14 batch loss 0.444722354 epoch total loss 0.510512829
# Trained batch 15 batch loss 0.413128495 epoch total loss 0.504020512
# Trained batch 16 batch loss 0.421514601 epoch total loss 0.498863906
# Trained batch 17 batch loss 0.432500392 epoch total loss 0.494960159
# Trained batch 18 batch loss 0.381673723 epoch total loss 0.488666475
# Trained batch 19 batch loss 0.395908415 epoch total loss 0.483784467
# Trained batch 20 batch loss 0.411750913 epoch total loss 0.480182797
# Trained batch 21 batch loss 0.401459306 epoch total loss 0.476434082
# Trained batch 22 batch loss 0.431576788 epoch total loss 0.474395096
# Trained batch 23 batch loss 0.415314049 epoch total loss 0.471826345
# Trained batch 24 batch loss 0.403095663 epoch total loss 0.46896255
# Trained batch 25 batch loss 0.390679 epoch total loss 0.46583122
# Trained batch 26 batch loss 0.401520193 epoch total loss 0.463357717
# Trained batch 27 batch loss 0.385921866 epoch total loss 0.46048969
# Trained batch 28 batch loss 0.39361462 epoch total loss 0.458101302
# Trained batch 29 batch loss 0.408953398 epoch total loss 0.456406564
# Trained batch 30 batch loss 0.403530359 epoch total loss 0.454644024
# Trained batch 31 batch loss 0.410180777 epoch total loss 0.453209728
# Trained batch 32 batch loss 0.390809625 epoch total loss 0.451259732
# Trained batch 33 batch loss 0.35378015 epoch total loss 0.448305786
# Trained batch 34 batch loss 0.375933558 epoch total loss 0.446177214
# Trained batch 35 batch loss 0.390620381 epoch total loss 0.444589853
# Trained batch 36 batch loss 0.378560841 epoch total loss 0.442755729
# Trained batch 37 batch loss 0.381521136 epoch total loss 0.441100717
# Trained batch 38 batch loss 0.377647847 epoch total loss 0.439430892
# Trained batch 39 batch loss 0.398369908 epoch total loss 0.438378066
# Trained batch 40 batch loss 0.403787941 epoch total loss 0.437513292
# Trained batch 41 batch loss 0.394790977 epoch total loss 0.436471283
# Trained batch 42 batch loss 0.351485074 epoch total loss 0.434447795
# Trained batch 43 batch loss 0.373922199 epoch total loss 0.433040231
# Trained batch 44 batch loss 0.402182043 epoch total loss 0.432338893
# Trained batch 45 batch loss 0.401927441 epoch total loss 0.431663096
# Trained batch 46 batch loss 0.399799496 epoch total loss 0.430970401
# Trained batch 47 batch loss 0.400088578 epoch total loss 0.430313349
# Trained batch 48 batch loss 0.344519138 epoch total loss 0.428525954
# Trained batch 49 batch loss 0.39163363 epoch total loss 0.427773058
# Trained batch 50 batch loss 0.370959461 epoch total loss 0.426636815
# Trained batch 51 batch loss 0.391686946 epoch total loss 0.42595154
# Trained batch 52 batch loss 0.412786305 epoch total loss 0.42569834
# Trained batch 53 batch loss 0.400002271 epoch total loss 0.425213516
# Trained batch 54 batch loss 0.376424134 epoch total loss 0.42431
# Trained batch 55 batch loss 0.367633462 epoch total loss 0.423279524
# Trained batch 56 batch loss 0.374378055 epoch total loss 0.422406286
# Trained batch 57 batch loss 0.377175242 epoch total loss 0.421612769
# Trained batch 58 batch loss 0.398734838 epoch total loss 0.421218306
# Trained batch 59 batch loss 0.390390247 epoch total loss 0.420695812
# Trained batch 60 batch loss 0.408927381 epoch total loss 0.420499682
# Trained batch 61 batch loss 0.406814277 epoch total loss 0.420275331
# Trained batch 62 batch loss 0.412565917 epoch total loss 0.420150965
# Trained batch 63 batch loss 0.415612 epoch total loss 0.420078903
# Trained batch 64 batch loss 0.414442331 epoch total loss 0.419990838
# Trained batch 65 batch loss 0.395460635 epoch total loss 0.419613451
# Trained batch 66 batch loss 0.409113139 epoch total loss 0.419454336
# Trained batch 67 batch loss 0.380527794 epoch total loss 0.41887334
# Trained batch 68 batch loss 0.397776753 epoch total loss 0.418563128
# Trained batch 69 batch loss 0.388663769 epoch total loss 0.418129802
# Trained batch 70 batch loss 0.384427935 epoch total loss 0.417648345
# Trained batch 71 batch loss 0.392890155 epoch total loss 0.417299658
# Trained batch 72 batch loss 0.41990009 epoch total loss 0.417335778
# Trained batch 73 batch loss 0.41889894 epoch total loss 0.417357206
# Trained batch 74 batch loss 0.404584616 epoch total loss 0.417184591
# Trained batch 75 batch loss 0.411121517 epoch total loss 0.417103767
# Trained batch 76 batch loss 0.417215616 epoch total loss 0.417105228
# Trained batch 77 batch loss 0.411076695 epoch total loss 0.417026907
# Trained batch 78 batch loss 0.359510899 epoch total loss 0.416289538
# Trained batch 79 batch loss 0.382338971 epoch total loss 0.415859789
# Trained batch 80 batch loss 0.408467799 epoch total loss 0.415767372
# Trained batch 81 batch loss 0.388258427 epoch total loss 0.415427774
# Trained batch 82 batch loss 0.385367543 epoch total loss 0.415061206
# Trained batch 83 batch loss 0.403898597 epoch total loss 0.414926738
# Trained batch 84 batch loss 0.392188579 epoch total loss 0.414656043
# Trained batch 85 batch loss 0.369558066 epoch total loss 0.414125472
# Trained batch 86 batch loss 0.386985272 epoch total loss 0.413809896
# Trained batch 87 batch loss 0.385899216 epoch total loss 0.413489074
# Trained batch 88 batch loss 0.409409404 epoch total loss 0.413442701
# Trained batch 89 batch loss 0.41344142 epoch total loss 0.413442671
# Trained batch 90 batch loss 0.394651 epoch total loss 0.413233876
# Trained batch 91 batch loss 0.409976423 epoch total loss 0.413198084
# Trained batch 92 batch loss 0.407280028 epoch total loss 0.41313374
# Trained batch 93 batch loss 0.42060104 epoch total loss 0.413214028
# Trained batch 94 batch loss 0.392193794 epoch total loss 0.412990421
# Trained batch 95 batch loss 0.36237359 epoch total loss 0.412457585
# Trained batch 96 batch loss 0.330303073 epoch total loss 0.411601812
# Trained batch 97 batch loss 0.313729376 epoch total loss 0.410592824
# Trained batch 98 batch loss 0.384163707 epoch total loss 0.410323113
# Trained batch 99 batch loss 0.392130375 epoch total loss 0.410139382
# Trained batch 100 batch loss 0.382974952 epoch total loss 0.409867734
# Trained batch 101 batch loss 0.379259974 epoch total loss 0.409564704
# Trained batch 102 batch loss 0.397325873 epoch total loss 0.40944472
# Trained batch 103 batch loss 0.39331615 epoch total loss 0.409288138
# Trained batch 104 batch loss 0.400574982 epoch total loss 0.409204334
# Trained batch 105 batch loss 0.385540456 epoch total loss 0.408978969
# Trained batch 106 batch loss 0.351810783 epoch total loss 0.408439636
# Trained batch 107 batch loss 0.344504952 epoch total loss 0.407842129
# Trained batch 108 batch loss 0.377224714 epoch total loss 0.40755862
# Trained batch 109 batch loss 0.372729301 epoch total loss 0.407239079
# Trained batch 110 batch loss 0.377955168 epoch total loss 0.406972885
# Trained batch 111 batch loss 0.386577845 epoch total loss 0.406789154
# Trained batch 112 batch loss 0.363733649 epoch total loss 0.406404734
# Trained batch 113 batch loss 0.381281137 epoch total loss 0.406182408
# Trained batch 114 batch loss 0.371353239 epoch total loss 0.405876905
# Trained batch 115 batch loss 0.378820598 epoch total loss 0.405641645
# Trained batch 116 batch loss 0.384061903 epoch total loss 0.405455619
# Trained batch 117 batch loss 0.370708197 epoch total loss 0.405158639
# Trained batch 118 batch loss 0.339258015 epoch total loss 0.404600143
# Trained batch 119 batch loss 0.388066858 epoch total loss 0.404461205
# Trained batch 120 batch loss 0.383983582 epoch total loss 0.404290557
# Trained batch 121 batch loss 0.333578914 epoch total loss 0.403706163
# Trained batch 122 batch loss 0.336257964 epoch total loss 0.4031533
# Trained batch 123 batch loss 0.339840263 epoch total loss 0.402638555
# Trained batch 124 batch loss 0.313092262 epoch total loss 0.401916414
# Trained batch 125 batch loss 0.330038071 epoch total loss 0.401341379
# Trained batch 126 batch loss 0.379545569 epoch total loss 0.401168406
# Trained batch 127 batch loss 0.372843951 epoch total loss 0.400945365
# Trained batch 128 batch loss 0.395408958 epoch total loss 0.400902122
# Trained batch 129 batch loss 0.350978017 epoch total loss 0.400515109
# Trained batch 130 batch loss 0.342163265 epoch total loss 0.400066257
# Trained batch 131 batch loss 0.352870107 epoch total loss 0.399705976
# Trained batch 132 batch loss 0.390769869 epoch total loss 0.399638295
# Trained batch 133 batch loss 0.354014158 epoch total loss 0.39929527
# Trained batch 134 batch loss 0.363135129 epoch total loss 0.39902541
# Trained batch 135 batch loss 0.343757778 epoch total loss 0.398616016
# Trained batch 136 batch loss 0.369749039 epoch total loss 0.398403764
# Trained batch 137 batch loss 0.356856018 epoch total loss 0.398100495
# Trained batch 138 batch loss 0.367213458 epoch total loss 0.39787668
# Trained batch 139 batch loss 0.366983026 epoch total loss 0.397654414
# Trained batch 140 batch loss 0.353192151 epoch total loss 0.397336811
# Trained batch 141 batch loss 0.366814464 epoch total loss 0.397120357
# Trained batch 142 batch loss 0.35727793 epoch total loss 0.396839768
# Trained batch 143 batch loss 0.376428 epoch total loss 0.396697
# Trained batch 144 batch loss 0.355156809 epoch total loss 0.396408528
# Trained batch 145 batch loss 0.385058612 epoch total loss 0.396330267
# Trained batch 146 batch loss 0.360320032 epoch total loss 0.396083623
# Trained batch 147 batch loss 0.327324212 epoch total loss 0.395615876
# Trained batch 148 batch loss 0.340453774 epoch total loss 0.395243168
# Trained batch 149 batch loss 0.279359102 epoch total loss 0.394465387
# Trained batch 150 batch loss 0.319230855 epoch total loss 0.393963814
# Trained batch 151 batch loss 0.361269474 epoch total loss 0.39374733
# Trained batch 152 batch loss 0.409586519 epoch total loss 0.393851519
# Trained batch 153 batch loss 0.375014365 epoch total loss 0.393728405
# Trained batch 154 batch loss 0.368002802 epoch total loss 0.393561363
# Trained batch 155 batch loss 0.370594323 epoch total loss 0.393413186
# Trained batch 156 batch loss 0.375980377 epoch total loss 0.393301457
# Trained batch 157 batch loss 0.329844594 epoch total loss 0.392897278
# Trained batch 158 batch loss 0.364272118 epoch total loss 0.39271611
# Trained batch 159 batch loss 0.331051856 epoch total loss 0.392328262
# Trained batch 160 batch loss 0.368765861 epoch total loss 0.392181
# Trained batch 161 batch loss 0.335719943 epoch total loss 0.391830325
# Trained batch 162 batch loss 0.364649117 epoch total loss 0.391662538
# Trained batch 163 batch loss 0.38606894 epoch total loss 0.391628236
# Trained batch 164 batch loss 0.356989264 epoch total loss 0.391417027
# Trained batch 165 batch loss 0.352099597 epoch total loss 0.391178697
# Trained batch 166 batch loss 0.366400599 epoch total loss 0.391029447
# Trained batch 167 batch loss 0.374108374 epoch total loss 0.390928119
# Trained batch 168 batch loss 0.383937985 epoch total loss 0.390886545
# Trained batch 169 batch loss 0.367832243 epoch total loss 0.39075014
# Trained batch 170 batch loss 0.370569348 epoch total loss 0.390631407
# Trained batch 171 batch loss 0.348121583 epoch total loss 0.390382826
# Trained batch 172 batch loss 0.348244905 epoch total loss 0.390137821
# Trained batch 173 batch loss 0.364359 epoch total loss 0.38998881
# Trained batch 174 batch loss 0.357247621 epoch total loss 0.389800638
# Trained batch 175 batch loss 0.374538213 epoch total loss 0.389713407
# Trained batch 176 batch loss 0.347327232 epoch total loss 0.389472574
# Trained batch 177 batch loss 0.325476676 epoch total loss 0.389111
# Trained batch 178 batch loss 0.336337447 epoch total loss 0.388814509
# Trained batch 179 batch loss 0.379054457 epoch total loss 0.388759971
# Trained batch 180 batch loss 0.384178787 epoch total loss 0.388734519
# Trained batch 181 batch loss 0.401533425 epoch total loss 0.38880524
# Trained batch 182 batch loss 0.37727806 epoch total loss 0.38874191
# Trained batch 183 batch loss 0.37769261 epoch total loss 0.388681561
# Trained batch 184 batch loss 0.334423721 epoch total loss 0.388386697
# Trained batch 185 batch loss 0.33158 epoch total loss 0.388079613
# Trained batch 186 batch loss 0.366515815 epoch total loss 0.387963682
# Trained batch 187 batch loss 0.371409118 epoch total loss 0.38787514
# Trained batch 188 batch loss 0.331831306 epoch total loss 0.387577057
# Trained batch 189 batch loss 0.357283056 epoch total loss 0.38741678
# Trained batch 190 batch loss 0.373680204 epoch total loss 0.38734448
# Trained batch 191 batch loss 0.369040728 epoch total loss 0.387248665
# Trained batch 192 batch loss 0.366057187 epoch total loss 0.387138277
# Trained batch 193 batch loss 0.335840821 epoch total loss 0.38687247
# Trained batch 194 batch loss 0.348298073 epoch total loss 0.386673629
# Trained batch 195 batch loss 0.336880028 epoch total loss 0.386418313
# Trained batch 196 batch loss 0.347117 epoch total loss 0.386217773
# Trained batch 197 batch loss 0.381189406 epoch total loss 0.386192232
# Trained batch 198 batch loss 0.372283727 epoch total loss 0.386122
# Trained batch 199 batch loss 0.388065428 epoch total loss 0.386131793
# Trained batch 200 batch loss 0.389964163 epoch total loss 0.386150926
# Trained batch 201 batch loss 0.416264564 epoch total loss 0.386300772
# Trained batch 202 batch loss 0.393133372 epoch total loss 0.386334598
# Trained batch 203 batch loss 0.382151246 epoch total loss 0.386313975
# Trained batch 204 batch loss 0.332361758 epoch total loss 0.386049509
# Trained batch 205 batch loss 0.325831264 epoch total loss 0.385755748
# Trained batch 206 batch loss 0.3078821 epoch total loss 0.385377705
# Trained batch 207 batch loss 0.305037826 epoch total loss 0.384989619
# Trained batch 208 batch loss 0.332769305 epoch total loss 0.384738564
# Trained batch 209 batch loss 0.354191154 epoch total loss 0.384592414
# Trained batch 210 batch loss 0.363087535 epoch total loss 0.38449
# Trained batch 211 batch loss 0.354355812 epoch total loss 0.3843472
# Trained batch 212 batch loss 0.338995963 epoch total loss 0.384133279
# Trained batch 213 batch loss 0.303037256 epoch total loss 0.383752555
# Trained batch 214 batch loss 0.325784773 epoch total loss 0.383481681
# Trained batch 215 batch loss 0.333425552 epoch total loss 0.383248866
# Trained batch 216 batch loss 0.352926821 epoch total loss 0.383108497
# Trained batch 217 batch loss 0.383045495 epoch total loss 0.383108228
# Trained batch 218 batch loss 0.359860629 epoch total loss 0.383001596
# Trained batch 219 batch loss 0.360977322 epoch total loss 0.382901
# Trained batch 220 batch loss 0.357110322 epoch total loss 0.3827838
# Trained batch 221 batch loss 0.375297189 epoch total loss 0.382749915
# Trained batch 222 batch loss 0.366597801 epoch total loss 0.382677168
# Trained batch 223 batch loss 0.364168495 epoch total loss 0.382594168
# Trained batch 224 batch loss 0.357735664 epoch total loss 0.382483184
# Trained batch 225 batch loss 0.345433623 epoch total loss 0.382318527
# Trained batch 226 batch loss 0.357667625 epoch total loss 0.38220945
# Trained batch 227 batch loss 0.323289305 epoch total loss 0.381949872
# Trained batch 228 batch loss 0.335014433 epoch total loss 0.381744027
# Trained batch 229 batch loss 0.351924807 epoch total loss 0.381613791
# Trained batch 230 batch loss 0.339197159 epoch total loss 0.381429344
# Trained batch 231 batch loss 0.338865787 epoch total loss 0.381245106
# Trained batch 232 batch loss 0.357381403 epoch total loss 0.381142259
# Trained batch 233 batch loss 0.379567027 epoch total loss 0.381135494
# Trained batch 234 batch loss 0.330166519 epoch total loss 0.380917698
# Trained batch 235 batch loss 0.349677265 epoch total loss 0.38078478
# Trained batch 236 batch loss 0.350368589 epoch total loss 0.380655915
# Trained batch 237 batch loss 0.329389751 epoch total loss 0.380439609
# Trained batch 238 batch loss 0.318865418 epoch total loss 0.380180866
# Trained batch 239 batch loss 0.342968881 epoch total loss 0.380025178
# Trained batch 240 batch loss 0.325251848 epoch total loss 0.379796952
# Trained batch 241 batch loss 0.333113849 epoch total loss 0.379603237
# Trained batch 242 batch loss 0.34285453 epoch total loss 0.379451394
# Trained batch 243 batch loss 0.359631 epoch total loss 0.379369855
# Trained batch 244 batch loss 0.337125391 epoch total loss 0.379196733
# Trained batch 245 batch loss 0.334592402 epoch total loss 0.379014671
# Trained batch 246 batch loss 0.389048457 epoch total loss 0.37905547
# Trained batch 247 batch loss 0.361308455 epoch total loss 0.378983587
# Trained batch 248 batch loss 0.334675342 epoch total loss 0.378804952
# Trained batch 249 batch loss 0.364248574 epoch total loss 0.37874648
# Trained batch 250 batch loss 0.353663802 epoch total loss 0.378646135
# Trained batch 251 batch loss 0.354481757 epoch total loss 0.378549874
# Trained batch 252 batch loss 0.354790449 epoch total loss 0.378455609
# Trained batch 253 batch loss 0.368887275 epoch total loss 0.37841779
# Trained batch 254 batch loss 0.377853 epoch total loss 0.378415555
# Trained batch 255 batch loss 0.375472695 epoch total loss 0.378404021
# Trained batch 256 batch loss 0.356729627 epoch total loss 0.378319353
# Trained batch 257 batch loss 0.378887922 epoch total loss 0.378321588
# Trained batch 258 batch loss 0.359397888 epoch total loss 0.378248215
# Trained batch 259 batch loss 0.365787268 epoch total loss 0.378200114
# Trained batch 260 batch loss 0.360076934 epoch total loss 0.378130406
# Trained batch 261 batch loss 0.368115455 epoch total loss 0.378092051
# Trained batch 262 batch loss 0.369129241 epoch total loss 0.378057837
# Trained batch 263 batch loss 0.36616984 epoch total loss 0.378012657
# Trained batch 264 batch loss 0.372772574 epoch total loss 0.377992809
# Trained batch 265 batch loss 0.367022276 epoch total loss 0.377951384
# Trained batch 266 batch loss 0.353868783 epoch total loss 0.377860844
# Trained batch 267 batch loss 0.348949701 epoch total loss 0.377752572
# Trained batch 268 batch loss 0.341021329 epoch total loss 0.377615511
# Trained batch 269 batch loss 0.346253604 epoch total loss 0.377498925
# Trained batch 270 batch loss 0.340278804 epoch total loss 0.377361059
# Trained batch 271 batch loss 0.349105299 epoch total loss 0.377256811
# Trained batch 272 batch loss 0.337839901 epoch total loss 0.377111882
# Trained batch 273 batch loss 0.34772554 epoch total loss 0.377004236
# Trained batch 274 batch loss 0.351062 epoch total loss 0.376909554
# Trained batch 275 batch loss 0.356408894 epoch total loss 0.376835
# Trained batch 276 batch loss 0.357108474 epoch total loss 0.376763523
# Trained batch 277 batch loss 0.349462092 epoch total loss 0.376664966
# Trained batch 278 batch loss 0.358415961 epoch total loss 0.376599312
# Trained batch 279 batch loss 0.344556242 epoch total loss 0.376484483
# Trained batch 280 batch loss 0.365391731 epoch total loss 0.376444876
# Trained batch 281 batch loss 0.341235876 epoch total loss 0.376319557
# Trained batch 282 batch loss 0.344344407 epoch total loss 0.376206189
# Trained batch 283 batch loss 0.298190624 epoch total loss 0.375930488
# Trained batch 284 batch loss 0.341202408 epoch total loss 0.375808209
# Trained batch 285 batch loss 0.314840853 epoch total loss 0.375594288
# Trained batch 286 batch loss 0.362293422 epoch total loss 0.375547796
# Trained batch 287 batch loss 0.386767387 epoch total loss 0.375586867
# Trained batch 288 batch loss 0.377783418 epoch total loss 0.375594497
# Trained batch 289 batch loss 0.356566191 epoch total loss 0.375528663
# Trained batch 290 batch loss 0.359273702 epoch total loss 0.375472635
# Trained batch 291 batch loss 0.357679605 epoch total loss 0.375411481
# Trained batch 292 batch loss 0.35749054 epoch total loss 0.375350118
# Trained batch 293 batch loss 0.349178493 epoch total loss 0.3752608
# Trained batch 294 batch loss 0.324860811 epoch total loss 0.375089377
# Trained batch 295 batch loss 0.352869332 epoch total loss 0.375014037
# Trained batch 296 batch loss 0.365192533 epoch total loss 0.374980867
# Trained batch 297 batch loss 0.352189571 epoch total loss 0.374904126
# Trained batch 298 batch loss 0.361678272 epoch total loss 0.37485975
# Trained batch 299 batch loss 0.351808906 epoch total loss 0.374782652
# Trained batch 300 batch loss 0.341347486 epoch total loss 0.374671191
# Trained batch 301 batch loss 0.306444317 epoch total loss 0.374444515
# Trained batch 302 batch loss 0.327584118 epoch total loss 0.374289364
# Trained batch 303 batch loss 0.391083449 epoch total loss 0.374344766
# Trained batch 304 batch loss 0.385373384 epoch total loss 0.374381065
# Trained batch 305 batch loss 0.332123399 epoch total loss 0.374242514
# Trained batch 306 batch loss 0.367912412 epoch total loss 0.374221832
# Trained batch 307 batch loss 0.372248918 epoch total loss 0.374215394
# Trained batch 308 batch loss 0.357134104 epoch total loss 0.374159932
# Trained batch 309 batch loss 0.362643152 epoch total loss 0.374122649
# Trained batch 310 batch loss 0.374553531 epoch total loss 0.37412402
# Trained batch 311 batch loss 0.364124507 epoch total loss 0.374091893
# Trained batch 312 batch loss 0.316667587 epoch total loss 0.373907834
# Trained batch 313 batch loss 0.362703979 epoch total loss 0.373872
# Trained batch 314 batch loss 0.339560449 epoch total loss 0.373762757
# Trained batch 315 batch loss 0.367051 epoch total loss 0.373741448
# Trained batch 316 batch loss 0.352934092 epoch total loss 0.373675615
# Trained batch 317 batch loss 0.358997762 epoch total loss 0.373629302
# Trained batch 318 batch loss 0.342680693 epoch total loss 0.373532
# Trained batch 319 batch loss 0.359041125 epoch total loss 0.373486549
# Trained batch 320 batch loss 0.368174374 epoch total loss 0.373469949
# Trained batch 321 batch loss 0.366360396 epoch total loss 0.373447806
# Trained batch 322 batch loss 0.352231801 epoch total loss 0.373381943
# Trained batch 323 batch loss 0.357637703 epoch total loss 0.373333186
# Trained batch 324 batch loss 0.322186023 epoch total loss 0.373175323
# Trained batch 325 batch loss 0.35121718 epoch total loss 0.373107761
# Trained batch 326 batch loss 0.316557139 epoch total loss 0.372934312
# Trained batch 327 batch loss 0.3601982 epoch total loss 0.37289536
# Trained batch 328 batch loss 0.312613219 epoch total loss 0.372711569
# Trained batch 329 batch loss 0.348027468 epoch total loss 0.372636557
# Trained batch 330 batch loss 0.361981243 epoch total loss 0.372604281
# Trained batch 331 batch loss 0.352570057 epoch total loss 0.372543752
# Trained batch 332 batch loss 0.3369838 epoch total loss 0.372436643
# Trained batch 333 batch loss 0.384778947 epoch total loss 0.372473717
# Trained batch 334 batch loss 0.291239232 epoch total loss 0.37223047
# Trained batch 335 batch loss 0.286009133 epoch total loss 0.371973097
# Trained batch 336 batch loss 0.293473303 epoch total loss 0.371739477
# Trained batch 337 batch loss 0.33707127 epoch total loss 0.371636629
# Trained batch 338 batch loss 0.32678175 epoch total loss 0.371503919
# Trained batch 339 batch loss 0.318063855 epoch total loss 0.371346265
# Trained batch 340 batch loss 0.334451467 epoch total loss 0.371237755
# Trained batch 341 batch loss 0.334956 epoch total loss 0.371131331
# Trained batch 342 batch loss 0.354251981 epoch total loss 0.371082
# Trained batch 343 batch loss 0.368484318 epoch total loss 0.371074408
# Trained batch 344 batch loss 0.329813659 epoch total loss 0.370954484
# Trained batch 345 batch loss 0.4192563 epoch total loss 0.371094465
# Trained batch 346 batch loss 0.396358609 epoch total loss 0.371167481
# Trained batch 347 batch loss 0.365287364 epoch total loss 0.371150523
# Trained batch 348 batch loss 0.373026341 epoch total loss 0.371155918
# Trained batch 349 batch loss 0.335033208 epoch total loss 0.371052444
# Trained batch 350 batch loss 0.335280329 epoch total loss 0.370950222
# Trained batch 351 batch loss 0.336066365 epoch total loss 0.370850831
# Trained batch 352 batch loss 0.335630536 epoch total loss 0.370750785
# Trained batch 353 batch loss 0.345691055 epoch total loss 0.370679766
# Trained batch 354 batch loss 0.366875201 epoch total loss 0.370669037
# Trained batch 355 batch loss 0.366066813 epoch total loss 0.370656103
# Trained batch 356 batch loss 0.341151744 epoch total loss 0.370573223
# Trained batch 357 batch loss 0.351747185 epoch total loss 0.370520502
# Trained batch 358 batch loss 0.330526054 epoch total loss 0.370408773
# Trained batch 359 batch loss 0.338398218 epoch total loss 0.370319575
# Trained batch 360 batch loss 0.333589911 epoch total loss 0.370217562
# Trained batch 361 batch loss 0.331114441 epoch total loss 0.37010923
# Trained batch 362 batch loss 0.343793601 epoch total loss 0.370036542
# Trained batch 363 batch loss 0.346880376 epoch total loss 0.369972765
# Trained batch 364 batch loss 0.359954178 epoch total loss 0.369945228
# Trained batch 365 batch loss 0.338825166 epoch total loss 0.369859964
# Trained batch 366 batch loss 0.339532048 epoch total loss 0.369777113
# Trained batch 367 batch loss 0.363446593 epoch total loss 0.369759887
# Trained batch 368 batch loss 0.352388442 epoch total loss 0.369712651
# Trained batch 369 batch loss 0.343556136 epoch total loss 0.369641781
# Trained batch 370 batch loss 0.323034078 epoch total loss 0.369515777
# Trained batch 371 batch loss 0.359516829 epoch total loss 0.369488835
# Trained batch 372 batch loss 0.328029901 epoch total loss 0.369377375
# Trained batch 373 batch loss 0.360612959 epoch total loss 0.36935389
# Trained batch 374 batch loss 0.311379969 epoch total loss 0.369198889
# Trained batch 375 batch loss 0.314519554 epoch total loss 0.369053066
# Trained batch 376 batch loss 0.358169258 epoch total loss 0.369024128
# Trained batch 377 batch loss 0.33615303 epoch total loss 0.368936926
# Trained batch 378 batch loss 0.287547231 epoch total loss 0.368721604
# Trained batch 379 batch loss 0.287180215 epoch total loss 0.368506491
# Trained batch 380 batch loss 0.28798306 epoch total loss 0.368294567
# Trained batch 381 batch loss 0.302572191 epoch total loss 0.368122041
# Trained batch 382 batch loss 0.311679274 epoch total loss 0.367974281
# Trained batch 383 batch loss 0.305040926 epoch total loss 0.367809951
# Trained batch 384 batch loss 0.316730589 epoch total loss 0.367676944
# Trained batch 385 batch loss 0.333571941 epoch total loss 0.367588341
# Trained batch 386 batch loss 0.329795718 epoch total loss 0.367490411
# Trained batch 387 batch loss 0.337891668 epoch total loss 0.367413938
# Trained batch 388 batch loss 0.318513423 epoch total loss 0.367287904
# Trained batch 389 batch loss 0.304616839 epoch total loss 0.367126793
# Trained batch 390 batch loss 0.350063056 epoch total loss 0.367083043
# Trained batch 391 batch loss 0.356530219 epoch total loss 0.367056072
# Trained batch 392 batch loss 0.353613317 epoch total loss 0.367021769
# Trained batch 393 batch loss 0.358659387 epoch total loss 0.367000461
# Trained batch 394 batch loss 0.359043062 epoch total loss 0.366980255
# Trained batch 395 batch loss 0.337982535 epoch total loss 0.366906852
# Trained batch 396 batch loss 0.358515739 epoch total loss 0.366885662
# Trained batch 397 batch loss 0.351356804 epoch total loss 0.366846591
# Trained batch 398 batch loss 0.298986554 epoch total loss 0.366676062
# Trained batch 399 batch loss 0.343899876 epoch total loss 0.366619
# Trained batch 400 batch loss 0.338182658 epoch total loss 0.366547883
# Trained batch 401 batch loss 0.338711739 epoch total loss 0.366478473
# Trained batch 402 batch loss 0.345629275 epoch total loss 0.366426617
# Trained batch 403 batch loss 0.340955049 epoch total loss 0.366363406
# Trained batch 404 batch loss 0.31377545 epoch total loss 0.366233259
# Trained batch 405 batch loss 0.338845551 epoch total loss 0.366165638
# Trained batch 406 batch loss 0.34160164 epoch total loss 0.366105139
# Trained batch 407 batch loss 0.318235248 epoch total loss 0.365987539
# Trained batch 408 batch loss 0.314526528 epoch total loss 0.365861416
# Trained batch 409 batch loss 0.336564362 epoch total loss 0.365789771
# Trained batch 410 batch loss 0.338254541 epoch total loss 0.365722626
# Trained batch 411 batch loss 0.338123411 epoch total loss 0.365655452
# Trained batch 412 batch loss 0.383296937 epoch total loss 0.365698278
# Trained batch 413 batch loss 0.393374115 epoch total loss 0.365765303
# Trained batch 414 batch loss 0.371927112 epoch total loss 0.365780205
# Trained batch 415 batch loss 0.363535523 epoch total loss 0.365774781
# Trained batch 416 batch loss 0.329059273 epoch total loss 0.365686536
# Trained batch 417 batch loss 0.3299523 epoch total loss 0.365600854
# Trained batch 418 batch loss 0.347667605 epoch total loss 0.365557939
# Trained batch 419 batch loss 0.385560185 epoch total loss 0.365605682
# Trained batch 420 batch loss 0.379381686 epoch total loss 0.365638465
# Trained batch 421 batch loss 0.384867758 epoch total loss 0.365684152
# Trained batch 422 batch loss 0.374613613 epoch total loss 0.365705341
# Trained batch 423 batch loss 0.36328879 epoch total loss 0.365699619
# Trained batch 424 batch loss 0.363577843 epoch total loss 0.365694582
# Trained batch 425 batch loss 0.370834917 epoch total loss 0.365706682
# Trained batch 426 batch loss 0.344464481 epoch total loss 0.365656823
# Trained batch 427 batch loss 0.294935673 epoch total loss 0.365491211
# Trained batch 428 batch loss 0.352058798 epoch total loss 0.36545983
# Trained batch 429 batch loss 0.379957318 epoch total loss 0.365493625
# Trained batch 430 batch loss 0.362188697 epoch total loss 0.365485936
# Trained batch 431 batch loss 0.334914595 epoch total loss 0.365415
# Trained batch 432 batch loss 0.324428499 epoch total loss 0.365320146
# Trained batch 433 batch loss 0.312611431 epoch total loss 0.365198404
# Trained batch 434 batch loss 0.332770377 epoch total loss 0.365123659
# Trained batch 435 batch loss 0.314679176 epoch total loss 0.365007699
# Trained batch 436 batch loss 0.324701875 epoch total loss 0.364915282
# Trained batch 437 batch loss 0.320140213 epoch total loss 0.364812821
# Trained batch 438 batch loss 0.329806656 epoch total loss 0.364732891
# Trained batch 439 batch loss 0.3132447 epoch total loss 0.364615619
# Trained batch 440 batch loss 0.35586229 epoch total loss 0.364595711
# Trained batch 441 batch loss 0.350682884 epoch total loss 0.364564151
# Trained batch 442 batch loss 0.357992113 epoch total loss 0.364549279
# Trained batch 443 batch loss 0.356340766 epoch total loss 0.364530742
# Trained batch 444 batch loss 0.363379598 epoch total loss 0.364528149
# Trained batch 445 batch loss 0.308822542 epoch total loss 0.36440295
# Trained batch 446 batch loss 0.302105248 epoch total loss 0.364263296
# Trained batch 447 batch loss 0.326712906 epoch total loss 0.364179254
# Trained batch 448 batch loss 0.351519972 epoch total loss 0.364151
# Trained batch 449 batch loss 0.37946707 epoch total loss 0.364185125
# Trained batch 450 batch loss 0.360525399 epoch total loss 0.364177
# Trained batch 451 batch loss 0.391489983 epoch total loss 0.364237547
# Trained batch 452 batch loss 0.367390662 epoch total loss 0.364244521
# Trained batch 453 batch loss 0.372084677 epoch total loss 0.364261806
# Trained batch 454 batch loss 0.373968691 epoch total loss 0.364283174
# Trained batch 455 batch loss 0.359300822 epoch total loss 0.364272237
# Trained batch 456 batch loss 0.355594486 epoch total loss 0.364253193
# Trained batch 457 batch loss 0.355800301 epoch total loss 0.364234716
# Trained batch 458 batch loss 0.341295242 epoch total loss 0.364184618
# Trained batch 459 batch loss 0.359002352 epoch total loss 0.364173353
# Trained batch 460 batch loss 0.355092913 epoch total loss 0.364153594
# Trained batch 461 batch loss 0.355643272 epoch total loss 0.364135116
# Trained batch 462 batch loss 0.357074022 epoch total loss 0.364119828
# Trained batch 463 batch loss 0.380226642 epoch total loss 0.364154637
# Trained batch 464 batch loss 0.398655921 epoch total loss 0.364228964
# Trained batch 465 batch loss 0.351674378 epoch total loss 0.364201963
# Trained batch 466 batch loss 0.361602724 epoch total loss 0.36419639
# Trained batch 467 batch loss 0.343263924 epoch total loss 0.364151567
# Trained batch 468 batch loss 0.340604246 epoch total loss 0.364101261
# Trained batch 469 batch loss 0.339672446 epoch total loss 0.364049166
# Trained batch 470 batch loss 0.337863743 epoch total loss 0.363993436
# Trained batch 471 batch loss 0.325377017 epoch total loss 0.36391145
# Trained batch 472 batch loss 0.348249316 epoch total loss 0.36387828
# Trained batch 473 batch loss 0.380402654 epoch total loss 0.363913208
# Trained batch 474 batch loss 0.344846249 epoch total loss 0.363873
# Trained batch 475 batch loss 0.331424594 epoch total loss 0.363804668
# Trained batch 476 batch loss 0.359259754 epoch total loss 0.363795102
# Trained batch 477 batch loss 0.350748718 epoch total loss 0.363767773
# Trained batch 478 batch loss 0.332605481 epoch total loss 0.363702595
# Trained batch 479 batch loss 0.353070021 epoch total loss 0.363680393
# Trained batch 480 batch loss 0.333306342 epoch total loss 0.363617122
# Trained batch 481 batch loss 0.338936388 epoch total loss 0.363565832
# Trained batch 482 batch loss 0.306164682 epoch total loss 0.363446742
# Trained batch 483 batch loss 0.324370891 epoch total loss 0.363365859
# Trained batch 484 batch loss 0.322023958 epoch total loss 0.363280416
# Trained batch 485 batch loss 0.345812172 epoch total loss 0.363244414
# Trained batch 486 batch loss 0.363134742 epoch total loss 0.363244176
# Trained batch 487 batch loss 0.340839684 epoch total loss 0.363198161
# Trained batch 488 batch loss 0.332625061 epoch total loss 0.363135517
# Trained batch 489 batch loss 0.320132524 epoch total loss 0.36304757
# Trained batch 490 batch loss 0.310410231 epoch total loss 0.362940133
# Trained batch 491 batch loss 0.369508237 epoch total loss 0.362953514
# Trained batch 492 batch loss 0.354283541 epoch total loss 0.362935871
# Trained batch 493 batch loss 0.380055875 epoch total loss 0.362970591
# Trained batch 494 batch loss 0.378414661 epoch total loss 0.363001853
# Trained batch 495 batch loss 0.393440753 epoch total loss 0.363063365
# Trained batch 496 batch loss 0.353443474 epoch total loss 0.363043964
# Trained batch 497 batch loss 0.363594174 epoch total loss 0.363045096
# Trained batch 498 batch loss 0.362748 epoch total loss 0.3630445
# Trained batch 499 batch loss 0.34478575 epoch total loss 0.363007903
# Trained batch 500 batch loss 0.343969822 epoch total loss 0.362969816
# Trained batch 501 batch loss 0.344226927 epoch total loss 0.362932414
# Trained batch 502 batch loss 0.338895649 epoch total loss 0.362884521
# Trained batch 503 batch loss 0.362580031 epoch total loss 0.362883925
# Trained batch 504 batch loss 0.358569384 epoch total loss 0.362875342
# Trained batch 505 batch loss 0.354049623 epoch total loss 0.362857878
# Trained batch 506 batch loss 0.343608439 epoch total loss 0.36281985
# Trained batch 507 batch loss 0.337121665 epoch total loss 0.362769157
# Trained batch 508 batch loss 0.341870129 epoch total loss 0.362728029
# Trained batch 509 batch loss 0.336492389 epoch total loss 0.362676471
# Trained batch 510 batch loss 0.327009559 epoch total loss 0.362606555
# Trained batch 511 batch loss 0.355490476 epoch total loss 0.362592608
# Trained batch 512 batch loss 0.363200843 epoch total loss 0.3625938
# Trained batch 513 batch loss 0.327647269 epoch total loss 0.362525702
# Trained batch 514 batch loss 0.341591477 epoch total loss 0.362484962
# Trained batch 515 batch loss 0.329951286 epoch total loss 0.362421811
# Trained batch 516 batch loss 0.331615955 epoch total loss 0.362362117
# Trained batch 517 batch loss 0.338294715 epoch total loss 0.362315536
# Trained batch 518 batch loss 0.3212291 epoch total loss 0.362236232
# Trained batch 519 batch loss 0.337232977 epoch total loss 0.362188071
# Trained batch 520 batch loss 0.347972661 epoch total loss 0.362160712
# Trained batch 521 batch loss 0.357903033 epoch total loss 0.362152576
# Trained batch 522 batch loss 0.351022452 epoch total loss 0.362131268
# Trained batch 523 batch loss 0.366190732 epoch total loss 0.362139016
# Trained batch 524 batch loss 0.354964614 epoch total loss 0.362125337
# Trained batch 525 batch loss 0.379464924 epoch total loss 0.362158388
# Trained batch 526 batch loss 0.337371677 epoch total loss 0.362111241
# Trained batch 527 batch loss 0.356576562 epoch total loss 0.36210075
# Trained batch 528 batch loss 0.339372844 epoch total loss 0.362057716
# Trained batch 529 batch loss 0.333368361 epoch total loss 0.362003505
# Trained batch 530 batch loss 0.333163112 epoch total loss 0.361949086
# Trained batch 531 batch loss 0.293777853 epoch total loss 0.361820698
# Trained batch 532 batch loss 0.30521363 epoch total loss 0.361714274
# Trained batch 533 batch loss 0.281207144 epoch total loss 0.361563206
# Trained batch 534 batch loss 0.295906961 epoch total loss 0.361440271
# Trained batch 535 batch loss 0.327116907 epoch total loss 0.361376137
# Trained batch 536 batch loss 0.369460464 epoch total loss 0.361391217
# Trained batch 537 batch loss 0.348086655 epoch total loss 0.361366421
# Trained batch 538 batch loss 0.358164459 epoch total loss 0.36136049
# Trained batch 539 batch loss 0.387400031 epoch total loss 0.3614088
# Trained batch 540 batch loss 0.329182774 epoch total loss 0.361349106
# Trained batch 541 batch loss 0.353441924 epoch total loss 0.361334503
# Trained batch 542 batch loss 0.346219957 epoch total loss 0.361306608
# Trained batch 543 batch loss 0.383294255 epoch total loss 0.361347109
# Trained batch 544 batch loss 0.36892283 epoch total loss 0.361361057
# Trained batch 545 batch loss 0.332167894 epoch total loss 0.361307502
# Trained batch 546 batch loss 0.332130671 epoch total loss 0.361254066
# Trained batch 547 batch loss 0.335881 epoch total loss 0.361207664
# Trained batch 548 batch loss 0.299313605 epoch total loss 0.361094743
# Trained batch 549 batch loss 0.306520671 epoch total loss 0.360995322
# Trained batch 550 batch loss 0.356665969 epoch total loss 0.360987425
# Trained batch 551 batch loss 0.323572099 epoch total loss 0.360919535
# Trained batch 552 batch loss 0.327882677 epoch total loss 0.360859692
# Trained batch 553 batch loss 0.350696325 epoch total loss 0.360841304
# Trained batch 554 batch loss 0.361978829 epoch total loss 0.36084336
# Trained batch 555 batch loss 0.319552 epoch total loss 0.360768974
# Trained batch 556 batch loss 0.346250355 epoch total loss 0.360742867
# Trained batch 557 batch loss 0.338265628 epoch total loss 0.360702515
# Trained batch 558 batch loss 0.338653773 epoch total loss 0.360663
# Trained batch 559 batch loss 0.336934149 epoch total loss 0.360620528
# Trained batch 560 batch loss 0.363605976 epoch total loss 0.360625863
# Trained batch 561 batch loss 0.373567432 epoch total loss 0.36064893
# Trained batch 562 batch loss 0.347806036 epoch total loss 0.360626072
# Trained batch 563 batch loss 0.353407502 epoch total loss 0.360613257
# Trained batch 564 batch loss 0.338352501 epoch total loss 0.360573798
# Trained batch 565 batch loss 0.350785524 epoch total loss 0.360556453
# Trained batch 566 batch loss 0.322625071 epoch total loss 0.360489458
# Trained batch 567 batch loss 0.359802842 epoch total loss 0.360488236
# Trained batch 568 batch loss 0.355420738 epoch total loss 0.360479325
# Trained batch 569 batch loss 0.381726831 epoch total loss 0.360516667
# Trained batch 570 batch loss 0.370882392 epoch total loss 0.360534847
# Trained batch 571 batch loss 0.353162527 epoch total loss 0.360521942
# Trained batch 572 batch loss 0.368874639 epoch total loss 0.360536575
# Trained batch 573 batch loss 0.376948 epoch total loss 0.360565215
# Trained batch 574 batch loss 0.379465282 epoch total loss 0.360598147
# Trained batch 575 batch loss 0.382355899 epoch total loss 0.360636
# Trained batch 576 batch loss 0.385199189 epoch total loss 0.360678613
# Trained batch 577 batch loss 0.35856998 epoch total loss 0.360674948
# Trained batch 578 batch loss 0.345604479 epoch total loss 0.3606489
# Trained batch 579 batch loss 0.334527969 epoch total loss 0.36060378
# Trained batch 580 batch loss 0.349589109 epoch total loss 0.360584825
# Trained batch 581 batch loss 0.344481826 epoch total loss 0.360557109
# Trained batch 582 batch loss 0.346158594 epoch total loss 0.360532373
# Trained batch 583 batch loss 0.334209 epoch total loss 0.360487223
# Trained batch 584 batch loss 0.330854177 epoch total loss 0.360436469
# Trained batch 585 batch loss 0.332901388 epoch total loss 0.360389411
# Trained batch 586 batch loss 0.358815044 epoch total loss 0.360386729
# Trained batch 587 batch loss 0.339387149 epoch total loss 0.360350937
# Trained batch 588 batch loss 0.34172374 epoch total loss 0.360319257
# Trained batch 589 batch loss 0.337727845 epoch total loss 0.360280901
# Trained batch 590 batch loss 0.372834116 epoch total loss 0.36030218
# Trained batch 591 batch loss 0.353835464 epoch total loss 0.360291213
# Trained batch 592 batch loss 0.369035423 epoch total loss 0.360306
# Trained batch 593 batch loss 0.371573836 epoch total loss 0.360324979
# Trained batch 594 batch loss 0.36027956 epoch total loss 0.360324889
# Trained batch 595 batch loss 0.327239305 epoch total loss 0.360269308
# Trained batch 596 batch loss 0.324020892 epoch total loss 0.360208482
# Trained batch 597 batch loss 0.323520392 epoch total loss 0.360147
# Trained batch 598 batch loss 0.330608219 epoch total loss 0.360097617
# Trained batch 599 batch loss 0.284442693 epoch total loss 0.359971315
# Trained batch 600 batch loss 0.326043189 epoch total loss 0.35991478
# Trained batch 601 batch loss 0.351857513 epoch total loss 0.359901369
# Trained batch 602 batch loss 0.399080336 epoch total loss 0.359966457
# Trained batch 603 batch loss 0.371503711 epoch total loss 0.35998559
# Trained batch 604 batch loss 0.35445112 epoch total loss 0.359976411
# Trained batch 605 batch loss 0.334454387 epoch total loss 0.359934241
# Trained batch 606 batch loss 0.395606488 epoch total loss 0.35999307
# Trained batch 607 batch loss 0.34678489 epoch total loss 0.359971315
# Trained batch 608 batch loss 0.355524749 epoch total loss 0.359964
# Trained batch 609 batch loss 0.339481086 epoch total loss 0.359930366
# Trained batch 610 batch loss 0.315154403 epoch total loss 0.359856963
# Trained batch 611 batch loss 0.341554195 epoch total loss 0.359827
# Trained batch 612 batch loss 0.319655657 epoch total loss 0.359761387
# Trained batch 613 batch loss 0.35801816 epoch total loss 0.359758526
# Trained batch 614 batch loss 0.351808757 epoch total loss 0.359745592
# Trained batch 615 batch loss 0.361669421 epoch total loss 0.359748691
# Trained batch 616 batch loss 0.347951502 epoch total loss 0.359729558
# Trained batch 617 batch loss 0.35106 epoch total loss 0.359715492
# Trained batch 618 batch loss 0.352954537 epoch total loss 0.359704554
# Trained batch 619 batch loss 0.342399895 epoch total loss 0.3596766
# Trained batch 620 batch loss 0.311386675 epoch total loss 0.359598726
# Trained batch 621 batch loss 0.328102112 epoch total loss 0.359547973
# Trained batch 622 batch loss 0.350980222 epoch total loss 0.359534204
# Trained batch 623 batch loss 0.32631883 epoch total loss 0.359480917
# Trained batch 624 batch loss 0.313640714 epoch total loss 0.359407455
# Trained batch 625 batch loss 0.337381452 epoch total loss 0.359372228
# Trained batch 626 batch loss 0.321783751 epoch total loss 0.359312147
# Trained batch 627 batch loss 0.325951666 epoch total loss 0.35925898
# Trained batch 628 batch loss 0.361826777 epoch total loss 0.359263062
# Trained batch 629 batch loss 0.333710313 epoch total loss 0.359222442
# Trained batch 630 batch loss 0.312981397 epoch total loss 0.359149039
# Trained batch 631 batch loss 0.329557717 epoch total loss 0.35910216
# Trained batch 632 batch loss 0.323839486 epoch total loss 0.35904637
# Trained batch 633 batch loss 0.328894347 epoch total loss 0.358998716
# Trained batch 634 batch loss 0.330198556 epoch total loss 0.358953297
# Trained batch 635 batch loss 0.304032922 epoch total loss 0.358866811
# Trained batch 636 batch loss 0.325129628 epoch total loss 0.358813763
# Trained batch 637 batch loss 0.337940603 epoch total loss 0.35878098
# Trained batch 638 batch loss 0.374373674 epoch total loss 0.358805418
# Trained batch 639 batch loss 0.347255528 epoch total loss 0.358787358
# Trained batch 640 batch loss 0.329099119 epoch total loss 0.358741
# Trained batch 641 batch loss 0.294131 epoch total loss 0.358640164
# Trained batch 642 batch loss 0.302011549 epoch total loss 0.358551979
# Trained batch 643 batch loss 0.329833984 epoch total loss 0.358507305
# Trained batch 644 batch loss 0.33458066 epoch total loss 0.358470172
# Trained batch 645 batch loss 0.299886942 epoch total loss 0.358379334
# Trained batch 646 batch loss 0.351586491 epoch total loss 0.358368814
# Trained batch 647 batch loss 0.351792753 epoch total loss 0.358358651
# Trained batch 648 batch loss 0.32035327 epoch total loss 0.3583
# Trained batch 649 batch loss 0.328721255 epoch total loss 0.358254433
# Trained batch 650 batch loss 0.309889376 epoch total loss 0.358180016
# Trained batch 651 batch loss 0.319397271 epoch total loss 0.358120441
# Trained batch 652 batch loss 0.329871655 epoch total loss 0.358077109
# Trained batch 653 batch loss 0.310983568 epoch total loss 0.358005017
# Trained batch 654 batch loss 0.336879373 epoch total loss 0.357972711
# Trained batch 655 batch loss 0.362609386 epoch total loss 0.357979774
# Trained batch 656 batch loss 0.349283546 epoch total loss 0.357966542
# Trained batch 657 batch loss 0.35728094 epoch total loss 0.357965499
# Trained batch 658 batch loss 0.360537827 epoch total loss 0.357969403
# Trained batch 659 batch loss 0.358645439 epoch total loss 0.357970417
# Trained batch 660 batch loss 0.347613335 epoch total loss 0.357954741
# Trained batch 661 batch loss 0.345187813 epoch total loss 0.357935399
# Trained batch 662 batch loss 0.351523221 epoch total loss 0.357925713
# Trained batch 663 batch loss 0.352424622 epoch total loss 0.357917428
# Trained batch 664 batch loss 0.375041246 epoch total loss 0.357943237
# Trained batch 665 batch loss 0.318733275 epoch total loss 0.357884288
# Trained batch 666 batch loss 0.34409225 epoch total loss 0.357863545
# Trained batch 667 batch loss 0.3603113 epoch total loss 0.357867211
# Trained batch 668 batch loss 0.376118183 epoch total loss 0.35789454
# Trained batch 669 batch loss 0.353528351 epoch total loss 0.357888
# Trained batch 670 batch loss 0.329321861 epoch total loss 0.357845366
# Trained batch 671 batch loss 0.357780695 epoch total loss 0.357845277
# Trained batch 672 batch loss 0.377108067 epoch total loss 0.357873946
# Trained batch 673 batch loss 0.357829 epoch total loss 0.357873887
# Trained batch 674 batch loss 0.333627403 epoch total loss 0.357837915
# Trained batch 675 batch loss 0.33919996 epoch total loss 0.357810318
# Trained batch 676 batch loss 0.350880295 epoch total loss 0.357800037
# Trained batch 677 batch loss 0.34501189 epoch total loss 0.357781172
# Trained batch 678 batch loss 0.319632798 epoch total loss 0.357724905
# Trained batch 679 batch loss 0.320637375 epoch total loss 0.357670277
# Trained batch 680 batch loss 0.305928797 epoch total loss 0.357594162
# Trained batch 681 batch loss 0.291816413 epoch total loss 0.357497573
# Trained batch 682 batch loss 0.289110243 epoch total loss 0.357397288
# Trained batch 683 batch loss 0.314177543 epoch total loss 0.357334018
# Trained batch 684 batch loss 0.307219774 epoch total loss 0.357260734
# Trained batch 685 batch loss 0.27534166 epoch total loss 0.357141167
# Trained batch 686 batch loss 0.252348751 epoch total loss 0.3569884
# Trained batch 687 batch loss 0.268923163 epoch total loss 0.35686022
# Trained batch 688 batch loss 0.254318953 epoch total loss 0.356711179
# Trained batch 689 batch loss 0.336954951 epoch total loss 0.356682509
# ...
# Trained batch 1375 batch loss 0.305514187 epoch total loss 0.276908398
# Trained batch 1376 batch loss 0.30495432 epoch total loss 0.276928782
# Trained batch 1377 batch loss 0.320767224 epoch total loss 0.276960641
# Trained batch 1378 batch loss 0.306502849 epoch total loss 0.276982069
# Trained batch 1379 batch loss 0.287934512 epoch total loss 0.27699
# Trained batch 1380 batch loss 0.272076398 epoch total loss 0.27698642
# Trained batch 1381 batch loss 0.256258577 epoch total loss 0.27697143
# Trained batch 1382 batch loss 0.304561824 epoch total loss 0.276991397
# Trained batch 1383 batch loss 0.294514984 epoch total loss 0.277004063
# Trained batch 1384 batch loss 0.286670655 epoch total loss 0.277011067
# Trained batch 1385 batch loss 0.278790474 epoch total loss 0.277012318
# Trained batch 1386 batch loss 0.285272777 epoch total loss 0.277018309
# Trained batch 1387 batch loss 0.25280723 epoch total loss 0.277000844
# Trained batch 1388 batch loss 0.248097286 epoch total loss 0.27698
# Trained batch 1389 batch loss 0.212111771 epoch total loss 0.276933312
# Trained batch 1390 batch loss 0.221591696 epoch total loss 0.276893497
# Trained batch 1391 batch loss 0.257635027 epoch total loss 0.276879638
# Trained batch 1392 batch loss 0.313122779 epoch total loss 0.276905686
# Trained batch 1393 batch loss 0.324528903 epoch total loss 0.276939869
# Trained batch 1394 batch loss 0.301376939 epoch total loss 0.276957393
# Trained batch 1395 batch loss 0.289733231 epoch total loss 0.276966572
# Trained batch 1396 batch loss 0.280903339 epoch total loss 0.276969373
# Trained batch 1397 batch loss 0.284969062 epoch total loss 0.276975125
# Trained batch 1398 batch loss 0.280243397 epoch total loss 0.27697745
# Trained batch 1399 batch loss 0.29652518 epoch total loss 0.276991427
# Trained batch 1400 batch loss 0.304820567 epoch total loss 0.277011305
# Trained batch 1401 batch loss 0.30223611 epoch total loss 0.277029306
# Trained batch 1402 batch loss 0.296815068 epoch total loss 0.277043432
# Trained batch 1403 batch loss 0.286939532 epoch total loss 0.277050465
# Trained batch 1404 batch loss 0.259378076 epoch total loss 0.277037889
# Trained batch 1405 batch loss 0.267761678 epoch total loss 0.277031273
# Trained batch 1406 batch loss 0.242781013 epoch total loss 0.277006894
# Trained batch 1407 batch loss 0.272618651 epoch total loss 0.277003795
# Trained batch 1408 batch loss 0.285016924 epoch total loss 0.277009457
# Trained batch 1409 batch loss 0.295934469 epoch total loss 0.277022898
# Trained batch 1410 batch loss 0.234516427 epoch total loss 0.276992768
# Trained batch 1411 batch loss 0.257330298 epoch total loss 0.276978821
# Trained batch 1412 batch loss 0.245804027 epoch total loss 0.276956737
# Trained batch 1413 batch loss 0.259323716 epoch total loss 0.27694428
# Trained batch 1414 batch loss 0.269707799 epoch total loss 0.276939154
# Trained batch 1415 batch loss 0.252036124 epoch total loss 0.27692157
# Trained batch 1416 batch loss 0.238450736 epoch total loss 0.27689442
# Trained batch 1417 batch loss 0.245006844 epoch total loss 0.27687189
# Trained batch 1418 batch loss 0.259748966 epoch total loss 0.27685982
# Trained batch 1419 batch loss 0.305284292 epoch total loss 0.276879847
# Trained batch 1420 batch loss 0.291175961 epoch total loss 0.27688992
# Trained batch 1421 batch loss 0.331463218 epoch total loss 0.276928306
# Trained batch 1422 batch loss 0.321945 epoch total loss 0.276959956
# Trained batch 1423 batch loss 0.304641396 epoch total loss 0.276979417
# Trained batch 1424 batch loss 0.317693263 epoch total loss 0.277008
# Trained batch 1425 batch loss 0.289461285 epoch total loss 0.277016729
# Trained batch 1426 batch loss 0.232569039 epoch total loss 0.276985556
# Trained batch 1427 batch loss 0.267423779 epoch total loss 0.27697885
# Trained batch 1428 batch loss 0.279885471 epoch total loss 0.276980907
# Trained batch 1429 batch loss 0.277964711 epoch total loss 0.276981562
# Trained batch 1430 batch loss 0.270701259 epoch total loss 0.276977181
# Trained batch 1431 batch loss 0.293652833 epoch total loss 0.276988834
# Trained batch 1432 batch loss 0.291436911 epoch total loss 0.276998907
# Trained batch 1433 batch loss 0.292912692 epoch total loss 0.277010024
# Trained batch 1434 batch loss 0.284501463 epoch total loss 0.277015239
# Trained batch 1435 batch loss 0.270821 epoch total loss 0.277010918
# Trained batch 1436 batch loss 0.289289594 epoch total loss 0.277019471
# Trained batch 1437 batch loss 0.313290387 epoch total loss 0.277044713
# Trained batch 1438 batch loss 0.257148564 epoch total loss 0.277030885
# Trained batch 1439 batch loss 0.295067489 epoch total loss 0.277043402
# Trained batch 1440 batch loss 0.30164656 epoch total loss 0.277060479
# Trained batch 1441 batch loss 0.297745943 epoch total loss 0.277074844
# Trained batch 1442 batch loss 0.275327355 epoch total loss 0.277073652
# Trained batch 1443 batch loss 0.278054595 epoch total loss 0.277074307
# Trained batch 1444 batch loss 0.30270645 epoch total loss 0.277092069
# Trained batch 1445 batch loss 0.312037975 epoch total loss 0.277116239
# Trained batch 1446 batch loss 0.315963417 epoch total loss 0.277143121
# Trained batch 1447 batch loss 0.285653323 epoch total loss 0.277149
# Trained batch 1448 batch loss 0.263052493 epoch total loss 0.277139246
# Trained batch 1449 batch loss 0.286961585 epoch total loss 0.277146041
# Trained batch 1450 batch loss 0.320026904 epoch total loss 0.277175605
# Trained batch 1451 batch loss 0.26071012 epoch total loss 0.277164251
# Trained batch 1452 batch loss 0.307835817 epoch total loss 0.27718538
# Trained batch 1453 batch loss 0.32376793 epoch total loss 0.277217448
# Trained batch 1454 batch loss 0.295679301 epoch total loss 0.277230144
# Trained batch 1455 batch loss 0.295927674 epoch total loss 0.277243
# Trained batch 1456 batch loss 0.228217512 epoch total loss 0.277209312
# Trained batch 1457 batch loss 0.223085955 epoch total loss 0.277172178
# Trained batch 1458 batch loss 0.232904941 epoch total loss 0.277141809
# Trained batch 1459 batch loss 0.255054712 epoch total loss 0.27712667
# Trained batch 1460 batch loss 0.259832799 epoch total loss 0.277114838
# Trained batch 1461 batch loss 0.274876952 epoch total loss 0.277113289
# Trained batch 1462 batch loss 0.26605618 epoch total loss 0.277105719
# Trained batch 1463 batch loss 0.266204149 epoch total loss 0.277098268
# Trained batch 1464 batch loss 0.289918661 epoch total loss 0.27710703
# Trained batch 1465 batch loss 0.2995646 epoch total loss 0.277122349
# Trained batch 1466 batch loss 0.339072585 epoch total loss 0.277164608
# Trained batch 1467 batch loss 0.303362936 epoch total loss 0.27718249
# Trained batch 1468 batch loss 0.33457908 epoch total loss 0.27722159
# Trained batch 1469 batch loss 0.307719916 epoch total loss 0.277242333
# Trained batch 1470 batch loss 0.268251836 epoch total loss 0.277236223
# Trained batch 1471 batch loss 0.279057771 epoch total loss 0.277237445
# Trained batch 1472 batch loss 0.310264707 epoch total loss 0.277259886
# Trained batch 1473 batch loss 0.282073379 epoch total loss 0.277263165
# Trained batch 1474 batch loss 0.272855341 epoch total loss 0.277260154
# Trained batch 1475 batch loss 0.243665904 epoch total loss 0.277237386
# Trained batch 1476 batch loss 0.259153813 epoch total loss 0.277225137
# Trained batch 1477 batch loss 0.273361027 epoch total loss 0.277222514
# Trained batch 1478 batch loss 0.246884257 epoch total loss 0.27720198
# Trained batch 1479 batch loss 0.256506175 epoch total loss 0.277187973
# Trained batch 1480 batch loss 0.261761516 epoch total loss 0.277177542
# Trained batch 1481 batch loss 0.266465187 epoch total loss 0.27717033
# Epoch 5 train loss 0.277170330286026
# Validated batch 1 batch loss 0.311232507
# Validated batch 2 batch loss 0.286310226
# Validated batch 3 batch loss 0.280532777
# Validated batch 4 batch loss 0.291849971
# Validated batch 5 batch loss 0.268297523
# Validated batch 6 batch loss 0.297657758
# Validated batch 7 batch loss 0.317084938
# Validated batch 8 batch loss 0.279827386
# Validated batch 9 batch loss 0.263386548
# Validated batch 10 batch loss 0.315958619
# Validated batch 11 batch loss 0.289221525
# Validated batch 12 batch loss 0.314132094
# Validated batch 13 batch loss 0.29288426
# Validated batch 14 batch loss 0.276417673
# Validated batch 15 batch loss 0.280644834
# Validated batch 16 batch loss 0.257374287
# Validated batch 17 batch loss 0.292883605
# Validated batch 18 batch loss 0.280560434
# Validated batch 19 batch loss 0.291106045
# Validated batch 20 batch loss 0.297212571
# Validated batch 21 batch loss 0.340160042
# Validated batch 22 batch loss 0.315470189
# Validated batch 23 batch loss 0.289088458
# Validated batch 24 batch loss 0.255364478
# Validated batch 25 batch loss 0.273199558
# Validated batch 26 batch loss 0.313594133
# Validated batch 27 batch loss 0.246013835
# Validated batch 28 batch loss 0.30743733
# Validated batch 29 batch loss 0.267739683
# Validated batch 30 batch loss 0.27575776
# Validated batch 31 batch loss 0.299790949
# Validated batch 32 batch loss 0.283887297
# Validated batch 33 batch loss 0.288324654
# Validated batch 34 batch loss 0.288729429
# Validated batch 35 batch loss 0.316182286
# Validated batch 36 batch loss 0.261315584
# Validated batch 37 batch loss 0.25744006
# Validated batch 38 batch loss 0.278105974
# Validated batch 39 batch loss 0.330402285
# Validated batch 40 batch loss 0.309115559
# Validated batch 41 batch loss 0.335791916
# Validated batch 42 batch loss 0.288745075
# Validated batch 43 batch loss 0.328566104
# Validated batch 44 batch loss 0.297304451
# Validated batch 45 batch loss 0.324866086
# Validated batch 46 batch loss 0.276193082
# Validated batch 47 batch loss 0.287227809
# Validated batch 48 batch loss 0.23407127
# Validated batch 49 batch loss 0.282098681
# Validated batch 50 batch loss 0.284366816
# Validated batch 51 batch loss 0.297371507
# Validated batch 52 batch loss 0.302709073
# Validated batch 53 batch loss 0.269505888
# Validated batch 54 batch loss 0.292820245
# Validated batch 55 batch loss 0.289075583
# Validated batch 56 batch loss 0.307524413
# Validated batch 57 batch loss 0.311350912
# Validated batch 58 batch loss 0.307853818
# Validated batch 59 batch loss 0.289384395
# Validated batch 60 batch loss 0.280176
# Validated batch 61 batch loss 0.305409074
# Validated batch 62 batch loss 0.295955509
# Validated batch 63 batch loss 0.295972139
# Validated batch 64 batch loss 0.318711549
# Validated batch 65 batch loss 0.307364613
# Validated batch 66 batch loss 0.30509755
# Validated batch 67 batch loss 0.309927911
# Validated batch 68 batch loss 0.283535838
# Validated batch 69 batch loss 0.280738145
# Validated batch 70 batch loss 0.289668739
# Validated batch 71 batch loss 0.243838117
# Validated batch 72 batch loss 0.303315967
# Validated batch 73 batch loss 0.301929295
# Validated batch 74 batch loss 0.2751939
# Validated batch 75 batch loss 0.299948305
# Validated batch 76 batch loss 0.287653416
# Validated batch 77 batch loss 0.287269771
# Validated batch 78 batch loss 0.287674844
# Validated batch 79 batch loss 0.312385
# Validated batch 80 batch loss 0.341963202
# Validated batch 81 batch loss 0.278102636
# Validated batch 82 batch loss 0.303158045
# Validated batch 83 batch loss 0.263053924
# Validated batch 84 batch loss 0.306841075
# Validated batch 85 batch loss 0.291634142
# Validated batch 86 batch loss 0.292824596
# Validated batch 87 batch loss 0.274388671
# Validated batch 88 batch loss 0.354440242
# Validated batch 89 batch loss 0.274569929
# Validated batch 90 batch loss 0.301428676
# Validated batch 91 batch loss 0.30931434
# Validated batch 92 batch loss 0.319705516
# Validated batch 93 batch loss 0.249816388
# Validated batch 94 batch loss 0.305542678
# Validated batch 95 batch loss 0.274054497
# Validated batch 96 batch loss 0.292239279
# Validated batch 97 batch loss 0.289256394
# Validated batch 98 batch loss 0.286985576
# Validated batch 99 batch loss 0.283014655
# Validated batch 100 batch loss 0.267883509
# Validated batch 101 batch loss 0.298903614
# Validated batch 102 batch loss 0.293899864
# Validated batch 103 batch loss 0.273140877
# Validated batch 104 batch loss 0.34015587
# Validated batch 105 batch loss 0.293278188
# Validated batch 106 batch loss 0.257422686
# Validated batch 107 batch loss 0.291079193
# Validated batch 108 batch loss 0.273118973
# Validated batch 109 batch loss 0.317339301
# Validated batch 110 batch loss 0.291176975
# Validated batch 111 batch loss 0.242474288
# Validated batch 112 batch loss 0.241002336
# Validated batch 113 batch loss 0.266775191
# Validated batch 114 batch loss 0.258257419
# Validated batch 115 batch loss 0.276595265
# Validated batch 116 batch loss 0.296919405
# Validated batch 117 batch loss 0.251062572
# Validated batch 118 batch loss 0.282794833
# Validated batch 119 batch loss 0.298996985
# Validated batch 120 batch loss 0.31056416
# Validated batch 121 batch loss 0.296263963
# Validated batch 122 batch loss 0.274386287
# Validated batch 123 batch loss 0.264081717
# Validated batch 124 batch loss 0.282857478
# Validated batch 125 batch loss 0.270550638
# Validated batch 126 batch loss 0.27221179
# Validated batch 127 batch loss 0.2712982
# Validated batch 128 batch loss 0.272155046
# Validated batch 129 batch loss 0.300162941
# Validated batch 130 batch loss 0.277156621
# Validated batch 131 batch loss 0.299337178
# Validated batch 132 batch loss 0.304534316
# Validated batch 133 batch loss 0.25626418
# Validated batch 134 batch loss 0.318542689
# Validated batch 135 batch loss 0.290140897
# Validated batch 136 batch loss 0.260228485
# Validated batch 137 batch loss 0.304245412
# Validated batch 138 batch loss 0.282734573
# Validated batch 139 batch loss 0.268408716
# Validated batch 140 batch loss 0.287463
# Validated batch 141 batch loss 0.325800598
# Validated batch 142 batch loss 0.291149378
# Validated batch 143 batch loss 0.27686587
# Validated batch 144 batch loss 0.29385075
# Validated batch 145 batch loss 0.291385263
# Validated batch 146 batch loss 0.293042064
# Validated batch 147 batch loss 0.260985613
# Validated batch 148 batch loss 0.295199
# Validated batch 149 batch loss 0.267022312
# Validated batch 150 batch loss 0.263052553
# Validated batch 151 batch loss 0.284606308
# Validated batch 152 batch loss 0.263856411
# Validated batch 153 batch loss 0.273010045
# Validated batch 154 batch loss 0.303703606
# Validated batch 155 batch loss 0.285845935
# Validated batch 156 batch loss 0.315501124
# Validated batch 157 batch loss 0.298547149
# Validated batch 158 batch loss 0.295031756
# Validated batch 159 batch loss 0.292026371
# Validated batch 160 batch loss 0.342698336
# Validated batch 161 batch loss 0.304348558
# Validated batch 162 batch loss 0.309592158
# Validated batch 163 batch loss 0.311305821
# Validated batch 164 batch loss 0.321551859
# Validated batch 165 batch loss 0.320493102
# Validated batch 166 batch loss 0.303705305
# Validated batch 167 batch loss 0.264330059
# Validated batch 168 batch loss 0.300956875
# Validated batch 169 batch loss 0.313043803
# Validated batch 170 batch loss 0.292966932
# Validated batch 171 batch loss 0.298388362
# Validated batch 172 batch loss 0.299418837
# Validated batch 173 batch loss 0.269076496
# Validated batch 174 batch loss 0.302246839
# Validated batch 175 batch loss 0.282518357
# Validated batch 176 batch loss 0.265699863
# Validated batch 177 batch loss 0.297929317
# Validated batch 178 batch loss 0.301753968
# Validated batch 179 batch loss 0.277898848
# Validated batch 180 batch loss 0.287203372
# Validated batch 181 batch loss 0.238979414
# Validated batch 182 batch loss 0.275392801
# Validated batch 183 batch loss 0.269803971
# Validated batch 184 batch loss 0.269533
# Validated batch 185 batch loss 0.276631266
# Validated batch 186 batch loss 0.27707082
# Validated batch 187 batch loss 0.287141889
# Validated batch 188 batch loss 0.32250917
# Validated batch 189 batch loss 0.313335329
# Validated batch 190 batch loss 0.261354268
# Validated batch 191 batch loss 0.319208503
# Validated batch 192 batch loss 0.247886568
# Validated batch 193 batch loss 0.236085609
# Validated batch 194 batch loss 0.289787859
# Validated batch 195 batch loss 0.248903
# Validated batch 196 batch loss 0.321357161
# Validated batch 197 batch loss 0.316532671
# Epoch 5 val loss 0.28953105211257935

# %%
R_ANKLE = 0
R_KNEE = 1
R_HIP = 2
L_HIP = 3
L_KNEE = 4
L_ANKLE = 5
PELVIS = 6
THORAX = 7
UPPER_NECK = 8
HEAD_TOP = 9
R_WRIST = 10
R_ELBOW = 11
R_SHOULDER = 12
L_SHOULDER = 13
L_ELBOW = 14
L_WRIST = 15

MPII_BONES = [
    [R_ANKLE, R_KNEE],
    [R_KNEE, R_HIP],
    [R_HIP, PELVIS],
    [L_HIP, PELVIS],
    [L_HIP, L_KNEE],
    [L_KNEE, L_ANKLE],
    [PELVIS, THORAX],
    [THORAX, UPPER_NECK],
    [UPPER_NECK, HEAD_TOP],
    [R_WRIST, R_ELBOW],
    [R_ELBOW, R_SHOULDER],
    [THORAX, R_SHOULDER],
    [THORAX, L_SHOULDER],
    [L_SHOULDER, L_ELBOW],
    [L_ELBOW, L_WRIST]
]

print('슝=3')
# Out:
# 슝=3

# %%
def find_max_coordinates(heatmaps):
    flatten_heatmaps = tf.reshape(heatmaps, (-1, 16))
    indices = tf.math.argmax(flatten_heatmaps, axis=0)
    y = tf.cast(indices / 64, dtype=tf.int64)
    x = indices - 64 * y
    return tf.stack([x, y], axis=1).numpy()

print('슝=3')
# Out:
# 슝=3

# %%
def extract_keypoints_from_heatmap(heatmaps):
    max_keypoints = find_max_coordinates(heatmaps)

    padded_heatmap = np.pad(heatmaps, [[1,1],[1,1],[0,0]], mode='constant')
    adjusted_keypoints = []
    for i, keypoint in enumerate(max_keypoints):
        max_y = keypoint[1]+1
        max_x = keypoint[0]+1
        
        patch = padded_heatmap[max_y-1:max_y+2, max_x-1:max_x+2, i]
        patch[1][1] = 0
        
        index = np.argmax(patch)
        
        next_y = index // 3
        next_x = index - next_y * 3
        delta_y = (next_y - 1) / 4
        delta_x = (next_x - 1) / 4
        
        adjusted_keypoint_x = keypoint[0] + delta_x
        adjusted_keypoint_y = keypoint[1] + delta_y
        adjusted_keypoints.append((adjusted_keypoint_x, adjusted_keypoint_y))
        
    adjusted_keypoints = np.clip(adjusted_keypoints, 0, 64)
    normalized_keypoints = adjusted_keypoints / 64
    return normalized_keypoints

print('슝=3')
# Out:
# 슝=3

# %%
def predict(model, image_path):
    encoded = tf.io.read_file(image_path)
    image = tf.io.decode_jpeg(encoded)
    inputs = tf.image.resize(image, (256, 256))
    inputs = tf.cast(inputs, tf.float32) / 127.5 - 1
    inputs = tf.expand_dims(inputs, 0)
    outputs = model(inputs, training=False)
    if type(outputs) != list:
        outputs = [outputs]
    heatmap = tf.squeeze(outputs[-1], axis=0).numpy()
    kp = extract_keypoints_from_heatmap(heatmap)
    return image, kp

print('슝=3')
# Out:
# 슝=3

# %%
def draw_keypoints_on_image(image, keypoints, index=None):
    fig,ax = plt.subplots(1)
    ax.imshow(image)
    joints = []
    for i, joint in enumerate(keypoints):
        joint_x = joint[0] * image.shape[1]
        joint_y = joint[1] * image.shape[0]
        if index is not None and index != i:
            continue
        plt.scatter(joint_x, joint_y, s=10, c='red', marker='o')
    plt.show()

def draw_skeleton_on_image(image, keypoints, index=None):
    fig,ax = plt.subplots(1)
    ax.imshow(image)
    joints = []
    for i, joint in enumerate(keypoints):
        joint_x = joint[0] * image.shape[1]
        joint_y = joint[1] * image.shape[0]
        joints.append((joint_x, joint_y))
    
    for bone in MPII_BONES:
        joint_1 = joints[bone[0]]
        joint_2 = joints[bone[1]]
        plt.plot([joint_1[0], joint_2[0]], [joint_1[1], joint_2[1]], linewidth=5, alpha=0.7)
    plt.show()

print('슝=3')
# Out:
# 슝=3

# %%
test_image = os.path.join(PROJECT_PATH, 'test_image.jpg')

image, keypoints = predict(simplebaseline_model, test_image)
draw_keypoints_on_image(image, keypoints)
draw_skeleton_on_image(image, keypoints)

# %% [markdown]
# * simplebaseline에 많은 시간을 써서, 루브릭에서 제시한 두가지 모델을 다 비교하지 못한 부분이 아쉬웠다.
#
#
# * 5epoch만 학습을 진행했지만 결과가 좋았다.

# %%
# simplebaseline 수정사항

# %% [markdown]
# 1.  loss 계산할 때 x랑 y가 타입이 안맞는 에러가 발생
#
#     -> 아래와 같이 compute_loss 함수를 수정
#
#          def compute_loss(self, labels, outputs):
#             loss = 0
#             weights = tf.cast(labels > 0, dtype=tf.float32) * 81 + 1
#
#
#             loss = tf.math.reduce_mean(
#                 tf.math.square(labels - outputs) * weights) * (
#                     1.0 / self.global_batch_size)
#
#             return loss

# %% [markdown]
# 2. Make sure the slot variables are created under the same strategy scope. This may happen if you're restoring from a checkpoint outside the scope 에러 발생
#
#
#     -> strategy = tf.distribute.MirroredStrategy() 에서
#
#     -> strategy = tf.distribute.get_strategy() 로 수정
