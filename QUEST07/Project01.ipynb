# %% [markdown]
# ### 프로젝트 : Segmentation map으로 도로 이미지 만들기

# %%
# 데이터 다운로드

! wget https://d3s0tskafalll9.cloudfront.net/media/documents/cityscapes.zip
! mkdir data
! unzip cityscapes.zip -d ./data
! rm cityscapes.zip

# %% [markdown]
# #### 1. 데이터에 한 가지 이상의 augmentation 방법을 적용하여 학습해 주세요. (어떠한 방법을 사용했는지 적어주세요.)
# #### 2. 이전에 구현했던 두 개의 Generator 중 Encoder와 Decoder간에 skip connection이 있는 U-Net Generator를 사용해 주세요.
# #### 3. 모델 학습 후, 학습된 Generator를 이용해 테스트합니다. 테스트 데이터는 다운로드했던 "val" 폴더 내 이미지를 사용해 주세요.
# #### 4. 1개 이상의 이미지에 대해 테스트 과정을 거친 후 그 결과를 스케치, 생성된 사진, 실제 사진 순서로 나란히 시각화해 주세요.
# #### 5. 모델을 충분히 학습하기에 시간이 부족할 수 있습니다. 적어도 10 epoch 이상 학습하며 중간 손실 값에 대한 로그를 남겨주세요. 좋은 결과를 얻기 위해선 긴 학습 시간이 필요하므로 테스트 결과는 만족스럽지 않아도 괜찮습니다.

# %%
# 필요 라이브러리 import
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import os

# %%
# 학습용 데이터 가져오기
! pwd
data_path = './data/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# /aiffel/aiffel/Quest/Quest07
# number of train examples : 1000

# %%
# 학습용 데이터셋에서 임의로 6장을 선택하여 시각화합니다.

plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
# 이미지의 크기를 확인해보기

f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
# 이미지 값을 -1 ~ 1로 정규화 하기
def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

# 정규화 된 값을 다시 되돌리기
def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

# 이미지를 읽는 코드
def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    # 1장으로 된 이미지를 칼러이미지, 스케치 이미지 반으로 나누어주기
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    
    # 두 이미지가 채널 축으로 연결됩니다. (tf.concat). 두 이미지가 각각 3채널인 경우 6채널이 됩니다.
    stacked = tf.concat([sketch, colored], axis=-1)
    
    # [위,아래][왼,우][앞,뒤] 행렬의 rank를 인수만큼 증가시킨다.
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    
    # 50% 확률로 Refection padding 또는 constant padding이 30픽셀의 pad width 만큼적용됩니다.
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)
        
    # (256,256,6) 크기를 가진 이미지를 임의로 잘라냅니다.
    out = image.random_crop(padded, size=[256, 256, 6])
    
    # 50% 확률로 가로로 뒤집습니다.
    out = image.random_flip_left_right(out)
    # 50% 확률로 세로로 뒤집습니다.
    out = image.random_flip_up_down(out)
    
    
    # 50% 확률로 회전시킵니다.
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]

# %%
# 위의 함수 적용 결과를 시각화 해보기 

plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
# 학습 데이터에 전처리 함수를 적용하기 / 맨 마지막 이미지만 결과로 확인하기

from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %% [markdown]
# ###  Generator 구성하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# "C64", "C128" 등으로 쓰여진 것과 같이 
# "Convolution → BatchNorm → LeakyReLU"의 3개 레이어로 구성된 기본적인 블록을 아래와 같이 하나의 레이어로 만들었습니다.

# EncodeBlock
from tensorflow.keras import layers, Input, Model

class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu= layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)
    
# n_filters, use_bn를 설정하여 사용할 필터의 개수와 BatchNorm 사용 여부를 결정

# %%
# DecodeBlock

class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

# %%
# U-Net Generator를 정의해 보겠습니다. 아래 모델의 __init__() 메서드에서 Encoder 및 Decoder에서 사용할 모든 블록들을 정의해 놓고,
# call()에서 forward propagation 하도록 합니다. 

class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block (EncodeBlock)      (None, 128, 128, 64) 3072        input_1[0][0]
# __________________________________________________________________________________________________
# encode_block_1 (EncodeBlock)    (None, 64, 64, 128)  131584      encode_block[0][0]
# __________________________________________________________________________________________________
# encode_block_2 (EncodeBlock)    (None, 32, 32, 256)  525312      encode_block_1[0][0]
# __________________________________________________________________________________________________
# encode_block_3 (EncodeBlock)    (None, 16, 16, 512)  2099200     encode_block_2[0][0]
# __________________________________________________________________________________________________
# encode_block_4 (EncodeBlock)    (None, 8, 8, 512)    4196352     encode_block_3[0][0]
# __________________________________________________________________________________________________
# encode_block_5 (EncodeBlock)    (None, 4, 4, 512)    4196352     encode_block_4[0][0]
# __________________________________________________________________________________________________
# encode_block_6 (EncodeBlock)    (None, 2, 2, 512)    4196352     encode_block_5[0][0]
# __________________________________________________________________________________________________
# encode_block_7 (EncodeBlock)    (None, 1, 1, 512)    4196352     encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block (DecodeBlock)      (None, 2, 2, 512)    4196352     encode_block_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           decode_block[0][0]
#                                                                  encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block_1 (DecodeBlock)    (None, 4, 4, 512)    8390656     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           decode_block_1[0][0]
#                                                                  encode_block_5[0][0]
# __________________________________________________________________________________________________
# decode_block_2 (DecodeBlock)    (None, 8, 8, 512)    8390656     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           decode_block_2[0][0]
#                                                                  encode_block_4[0][0]
# __________________________________________________________________________________________________
# decode_block_3 (DecodeBlock)    (None, 16, 16, 512)  8390656     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           decode_block_3[0][0]
#                                                                  encode_block_3[0][0]
# __________________________________________________________________________________________________
# decode_block_4 (DecodeBlock)    (None, 32, 32, 256)  4195328     concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           decode_block_4[0][0]
#                                                                  encode_block_2[0][0]
# __________________________________________________________________________________________________
# decode_block_5 (DecodeBlock)    (None, 64, 64, 128)  1049088     concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           decode_block_5[0][0]
#                                                                  encode_block_1[0][0]
# __________________________________________________________________________________________________
# decode_block_6 (DecodeBlock)    (None, 128, 128, 64) 262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           decode_block_6[0][0]
#                                                                  encode_block[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 3)  6144        concatenate_6[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %% [markdown]
# ### Discriminator 구성하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Discriminator에 사용할 기본적인 블록

#__init__() 에서 필요한 만큼 많은 설정을 가능하게끔 했습니다. 
# 필터의 수(n_filters), 필터가 순회하는 간격(stride), 출력 feature map의 크기를 조절할 수 있도록 하는 패딩 설정(custom_pad),
# BatchNorm의 사용 여부(use_bn), 활성화 함수 사용 여부(act)가 설정 가능


class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()

# %%
Discriminator().get_summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 6)  0           input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate_7[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
# 시험 삼아 임의의 (256,256,3) 크기의 입력을 넣어 나오는 (30,30) 출력을 시각화해보겠습니다.

x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %% [markdown]
# ### Optimizer , Loss 적용하기 / 학습하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

# %%
# optimizer는 논문과 동일하게 아래와 같이 설정

from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %%
# 하나의 배치 크기만큼 데이터를 입력했을 때 가중치를 1회 업데이트하는 과정

@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %%
EPOCHS = 20

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 10 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[10]
# Generator_loss:1.0213
# L1_loss:0.3544
# Discriminator_loss:1.3424
#
# EPOCH[1] - STEP[20]
# Generator_loss:1.0808
# L1_loss:0.3428
# Discriminator_loss:1.1461
#
# EPOCH[1] - STEP[30]
# Generator_loss:1.6476
# L1_loss:0.2224
# Discriminator_loss:0.9169
#
# EPOCH[1] - STEP[40]
# Generator_loss:2.1910
# L1_loss:0.2710
# Discriminator_loss:0.6800
#
# EPOCH[1] - STEP[50]
# Generator_loss:1.9387
# L1_loss:0.2545
# Discriminator_loss:0.4427
#
# EPOCH[1] - STEP[60]
# Generator_loss:2.1439
# L1_loss:0.2140
# Discriminator_loss:0.4172
#
# EPOCH[1] - STEP[70]
# Generator_loss:2.0783
# L1_loss:0.2586
# Discriminator_loss:1.6202
#
# EPOCH[1] - STEP[80]
# Generator_loss:1.8183
# L1_loss:0.2382
# Discriminator_loss:0.9157
#
# EPOCH[1] - STEP[90]
# Generator_loss:1.3084
# L1_loss:0.2696
# Discriminator_loss:0.6691
#
# EPOCH[1] - STEP[100]
# Generator_loss:2.0926
# L1_loss:0.2787
# Discriminator_loss:0.9941
#
# EPOCH[1] - STEP[110]
# Generator_loss:1.5972
# L1_loss:0.2538
# Discriminator_loss:0.5563
#
# EPOCH[1] - STEP[120]
# Generator_loss:1.0506
# L1_loss:0.2775
# Discriminator_loss:1.2898
#
# EPOCH[1] - STEP[130]
# Generator_loss:0.7600
# L1_loss:0.2593
# Discriminator_loss:0.8519
#
# EPOCH[1] - STEP[140]
# Generator_loss:1.7462
# L1_loss:0.2269
# Discriminator_loss:0.9114
#
# EPOCH[1] - STEP[150]
# Generator_loss:1.4387
# L1_loss:0.2924
# Discriminator_loss:0.5374
#
# EPOCH[1] - STEP[160]
# Generator_loss:2.4428
# L1_loss:0.2119
# Discriminator_loss:0.7146
#
# EPOCH[1] - STEP[170]
# Generator_loss:1.6183
# L1_loss:0.2335
# Discriminator_loss:0.9688
#
# EPOCH[1] - STEP[180]
# Generator_loss:1.3694
# L1_loss:0.2041
# Discriminator_loss:0.5456
#
# EPOCH[1] - STEP[190]
# Generator_loss:1.4999
# L1_loss:0.2300
# Discriminator_loss:0.8887
#
# EPOCH[1] - STEP[200]
# Generator_loss:2.2977
# L1_loss:0.2511
# Discriminator_loss:0.4575
#
# EPOCH[1] - STEP[210]
# Generator_loss:0.7986
# L1_loss:0.2096
# Discriminator_loss:1.2540
#
# EPOCH[1] - STEP[220]
# Generator_loss:1.9826
# L1_loss:0.2392
# Discriminator_loss:0.4074
#
# EPOCH[1] - STEP[230]
# Generator_loss:3.1997
# L1_loss:0.2372
# Discriminator_loss:1.2291
#
# EPOCH[1] - STEP[240]
# Generator_loss:1.3612
# L1_loss:0.2811
# Discriminator_loss:0.7533
#
# EPOCH[1] - STEP[250]
# Generator_loss:1.6148
# L1_loss:0.2009
# Discriminator_loss:0.6886
#
# EPOCH[2] - STEP[10]
# Generator_loss:1.0442
# L1_loss:0.2305
# Discriminator_loss:0.6967
#
# EPOCH[2] - STEP[20]
# Generator_loss:2.2817
# L1_loss:0.2930
# Discriminator_loss:0.4839
#
# EPOCH[2] - STEP[30]
# Generator_loss:2.1878
# L1_loss:0.2372
# Discriminator_loss:1.1748
#
# EPOCH[2] - STEP[40]
# Generator_loss:1.6265
# L1_loss:0.2546
# Discriminator_loss:0.6389
#
# EPOCH[2] - STEP[50]
# Generator_loss:1.3718
# L1_loss:0.2538
# Discriminator_loss:0.7560
#
# EPOCH[2] - STEP[60]
# Generator_loss:3.1809
# L1_loss:0.1756
# Discriminator_loss:0.7778
#
# EPOCH[2] - STEP[70]
# Generator_loss:1.3450
# L1_loss:0.1911
# Discriminator_loss:0.7654
#
# EPOCH[2] - STEP[80]
# Generator_loss:0.8652
# L1_loss:0.2248
# Discriminator_loss:0.7598
#
# EPOCH[2] - STEP[90]
# Generator_loss:1.4447
# L1_loss:0.1870
# Discriminator_loss:0.8382
#
# EPOCH[2] - STEP[100]
# Generator_loss:2.2967
# L1_loss:0.1735
# Discriminator_loss:1.4159
#
# EPOCH[2] - STEP[110]
# Generator_loss:1.6030
# L1_loss:0.2237
# Discriminator_loss:0.4333
#
# EPOCH[2] - STEP[120]
# Generator_loss:1.7509
# L1_loss:0.2204
# Discriminator_loss:0.7174
#
# EPOCH[2] - STEP[130]
# Generator_loss:0.4809
# L1_loss:0.2127
# Discriminator_loss:1.5234
#
# EPOCH[2] - STEP[140]
# Generator_loss:2.8901
# L1_loss:0.2142
# Discriminator_loss:0.8884
#
# EPOCH[2] - STEP[150]
# Generator_loss:2.7175
# L1_loss:0.2356
# Discriminator_loss:0.6369
#
# EPOCH[2] - STEP[160]
# Generator_loss:1.8402
# L1_loss:0.1961
# Discriminator_loss:0.8216
#
# EPOCH[2] - STEP[170]
# Generator_loss:1.5987
# L1_loss:0.1840
# Discriminator_loss:0.4433
#
# EPOCH[2] - STEP[180]
# Generator_loss:2.0360
# L1_loss:0.2174
# Discriminator_loss:0.8586
#
# EPOCH[2] - STEP[190]
# Generator_loss:1.0431
# L1_loss:0.1941
# Discriminator_loss:0.7933
#
# EPOCH[2] - STEP[200]
# Generator_loss:1.9139
# L1_loss:0.1826
# Discriminator_loss:0.5381
#
# EPOCH[2] - STEP[210]
# Generator_loss:1.3513
# L1_loss:0.1991
# Discriminator_loss:0.5999
#
# EPOCH[2] - STEP[220]
# Generator_loss:2.4264
# L1_loss:0.3011
# Discriminator_loss:0.7774
#
# EPOCH[2] - STEP[230]
# Generator_loss:1.7517
# L1_loss:0.2247
# Discriminator_loss:0.8152
#
# EPOCH[2] - STEP[240]
# Generator_loss:2.4245
# L1_loss:0.1808
# Discriminator_loss:0.9044
#
# EPOCH[2] - STEP[250]
# Generator_loss:3.2573
# L1_loss:0.1701
# Discriminator_loss:0.9984
#
# EPOCH[3] - STEP[10]
# Generator_loss:1.5118
# L1_loss:0.2068
# Discriminator_loss:0.5079
#
# EPOCH[3] - STEP[20]
# Generator_loss:1.0028
# L1_loss:0.1581
# Discriminator_loss:0.7443
#
# EPOCH[3] - STEP[30]
# Generator_loss:2.3491
# L1_loss:0.1715
# Discriminator_loss:0.9017
#
# EPOCH[3] - STEP[40]
# Generator_loss:1.0739
# L1_loss:0.2085
# Discriminator_loss:0.8380
#
# EPOCH[3] - STEP[50]
# Generator_loss:1.7210
# L1_loss:0.1818
# Discriminator_loss:0.4303
#
# EPOCH[3] - STEP[60]
# Generator_loss:1.7344
# L1_loss:0.1787
# Discriminator_loss:0.9105
# EPOCH[3] - STEP[70]
# Generator_loss:0.4928
# L1_loss:0.1832
# Discriminator_loss:1.3314
#
# EPOCH[3] - STEP[80]
# Generator_loss:2.6532
# L1_loss:0.1928
# Discriminator_loss:0.3548
#
# EPOCH[3] - STEP[90]
# Generator_loss:2.5726
# L1_loss:0.1834
# Discriminator_loss:0.4994
#
# EPOCH[3] - STEP[100]
# Generator_loss:1.1774
# L1_loss:0.2383
# Discriminator_loss:0.6680
#
# EPOCH[3] - STEP[110]
# Generator_loss:1.9289
# L1_loss:0.1975
# Discriminator_loss:0.4579
#
# EPOCH[3] - STEP[120]
# Generator_loss:1.7154
# L1_loss:0.2660
# Discriminator_loss:0.3468
#
# EPOCH[3] - STEP[130]
# Generator_loss:1.6545
# L1_loss:0.2022
# Discriminator_loss:1.1212
#
# EPOCH[3] - STEP[140]
# Generator_loss:1.5948
# L1_loss:0.1946
# Discriminator_loss:0.8446
#
# EPOCH[3] - STEP[150]
# Generator_loss:1.6347
# L1_loss:0.2052
# Discriminator_loss:1.7208
#
# EPOCH[3] - STEP[160]
# Generator_loss:2.5232
# L1_loss:0.2398
# Discriminator_loss:0.4833
#
# EPOCH[3] - STEP[170]
# Generator_loss:1.3376
# L1_loss:0.1701
# Discriminator_loss:0.4329
#
# EPOCH[3] - STEP[180]
# Generator_loss:0.7096
# L1_loss:0.1946
# Discriminator_loss:1.2378
#
# EPOCH[3] - STEP[190]
# Generator_loss:1.4440
# L1_loss:0.1955
# Discriminator_loss:0.7056
#
# EPOCH[3] - STEP[200]
# Generator_loss:1.2049
# L1_loss:0.2249
# Discriminator_loss:0.7419
#
# EPOCH[3] - STEP[210]
# Generator_loss:1.9267
# L1_loss:0.1811
# Discriminator_loss:0.2783
#
# EPOCH[3] - STEP[220]
# Generator_loss:1.6713
# L1_loss:0.2073
# Discriminator_loss:0.5983
#
# EPOCH[3] - STEP[230]
# Generator_loss:1.6668
# L1_loss:0.1965
# Discriminator_loss:0.4915
#
# EPOCH[3] - STEP[240]
# Generator_loss:1.2681
# L1_loss:0.2344
# Discriminator_loss:0.5822
#
# EPOCH[3] - STEP[250]
# Generator_loss:0.9403
# L1_loss:0.1771
# Discriminator_loss:1.0619
#
# EPOCH[4] - STEP[10]
# Generator_loss:2.5108
# L1_loss:0.2018
# Discriminator_loss:0.5502
#
# EPOCH[4] - STEP[20]
# Generator_loss:1.3015
# L1_loss:0.1987
# Discriminator_loss:0.5799
#
# EPOCH[4] - STEP[30]
# Generator_loss:2.0296
# L1_loss:0.1818
# Discriminator_loss:0.6125
#
# EPOCH[4] - STEP[40]
# Generator_loss:2.1401
# L1_loss:0.1924
# Discriminator_loss:0.3896
#
# EPOCH[4] - STEP[50]
# Generator_loss:1.2935
# L1_loss:0.1561
# Discriminator_loss:1.0713
#
# EPOCH[4] - STEP[60]
# Generator_loss:1.6222
# L1_loss:0.1918
# Discriminator_loss:0.3676
#
# EPOCH[4] - STEP[70]
# Generator_loss:0.7706
# L1_loss:0.1619
# Discriminator_loss:1.0764
#
# EPOCH[4] - STEP[80]
# Generator_loss:2.5778
# L1_loss:0.2214
# Discriminator_loss:1.4445
#
# EPOCH[4] - STEP[90]
# Generator_loss:2.0037
# L1_loss:0.1911
# Discriminator_loss:0.7473
#
# EPOCH[4] - STEP[100]
# Generator_loss:1.7058
# L1_loss:0.1945
# Discriminator_loss:0.7905
#
# EPOCH[4] - STEP[110]
# Generator_loss:1.8691
# L1_loss:0.2217
# Discriminator_loss:0.4814
#
# EPOCH[4] - STEP[120]
# Generator_loss:1.8977
# L1_loss:0.2089
# Discriminator_loss:0.4726
#
# EPOCH[4] - STEP[130]
# Generator_loss:2.5800
# L1_loss:0.1881
# Discriminator_loss:0.6654
#
# EPOCH[4] - STEP[140]
# Generator_loss:2.2081
# L1_loss:0.2055
# Discriminator_loss:0.7494
#
# EPOCH[4] - STEP[150]
# Generator_loss:0.3468
# L1_loss:0.1837
# Discriminator_loss:1.5350
#
# EPOCH[4] - STEP[160]
# Generator_loss:2.1177
# L1_loss:0.1856
# Discriminator_loss:0.5431
#
# EPOCH[4] - STEP[170]
# Generator_loss:2.8606
# L1_loss:0.2036
# Discriminator_loss:0.5392
#
# EPOCH[4] - STEP[180]
# Generator_loss:2.1155
# L1_loss:0.2047
# Discriminator_loss:0.3972
#
# EPOCH[4] - STEP[190]
# Generator_loss:1.4657
# L1_loss:0.2098
# Discriminator_loss:0.7714
#
# EPOCH[4] - STEP[200]
# Generator_loss:2.0744
# L1_loss:0.1563
# Discriminator_loss:0.6381
#
# EPOCH[4] - STEP[210]
# Generator_loss:3.0876
# L1_loss:0.1903
# Discriminator_loss:1.2236
#
# EPOCH[4] - STEP[220]
# Generator_loss:2.4106
# L1_loss:0.1866
# Discriminator_loss:1.6730
#
# EPOCH[4] - STEP[230]
# Generator_loss:0.8746
# L1_loss:0.2228
# Discriminator_loss:0.7851
#
# EPOCH[4] - STEP[240]
# Generator_loss:2.5316
# L1_loss:0.1655
# Discriminator_loss:0.7405
#
# EPOCH[4] - STEP[250]
# Generator_loss:1.1175
# L1_loss:0.2035
# Discriminator_loss:1.4298
#
# EPOCH[5] - STEP[10]
# Generator_loss:1.8907
# L1_loss:0.2263
# Discriminator_loss:0.3079
#
# EPOCH[5] - STEP[20]
# Generator_loss:2.0734
# L1_loss:0.1563
# Discriminator_loss:1.3681
#
# EPOCH[5] - STEP[30]
# Generator_loss:2.4426
# L1_loss:0.1929
# Discriminator_loss:0.3420
#
# EPOCH[5] - STEP[40]
# Generator_loss:0.7273
# L1_loss:0.1942
# Discriminator_loss:0.9873
#
# EPOCH[5] - STEP[50]
# Generator_loss:0.7570
# L1_loss:0.1959
# Discriminator_loss:0.9016
#
# EPOCH[5] - STEP[60]
# Generator_loss:3.0389
# L1_loss:0.2068
# Discriminator_loss:0.5835
#
# EPOCH[5] - STEP[70]
# Generator_loss:2.0937
# L1_loss:0.1858
# Discriminator_loss:0.3105
#
# EPOCH[5] - STEP[80]
# Generator_loss:2.4680
# L1_loss:0.2140
# Discriminator_loss:0.3151
#
# EPOCH[5] - STEP[90]
# Generator_loss:1.1180
# L1_loss:0.2103
# Discriminator_loss:0.7874
#
# EPOCH[5] - STEP[100]
# Generator_loss:0.1908
# L1_loss:0.2064
# Discriminator_loss:2.0006
#
# EPOCH[5] - STEP[110]
# Generator_loss:0.9868
# L1_loss:0.1996
# Discriminator_loss:0.7147
#
# EPOCH[5] - STEP[120]
# Generator_loss:2.2035
# L1_loss:0.2202
# Discriminator_loss:0.5257
# EPOCH[5] - STEP[130]
# Generator_loss:0.6354
# L1_loss:0.1676
# Discriminator_loss:1.3040
#
# EPOCH[5] - STEP[140]
# Generator_loss:1.5581
# L1_loss:0.1869
# Discriminator_loss:1.5960
#
# EPOCH[5] - STEP[150]
# Generator_loss:1.1892
# L1_loss:0.2096
# Discriminator_loss:0.5975
#
# EPOCH[5] - STEP[160]
# Generator_loss:1.7463
# L1_loss:0.1804
# Discriminator_loss:0.5277
#
# EPOCH[5] - STEP[170]
# Generator_loss:2.5905
# L1_loss:0.1974
# Discriminator_loss:0.8785
#
# EPOCH[5] - STEP[180]
# Generator_loss:1.2894
# L1_loss:0.2164
# Discriminator_loss:0.7662
#
# EPOCH[5] - STEP[190]
# Generator_loss:2.2362
# L1_loss:0.1738
# Discriminator_loss:0.4685
#
# EPOCH[5] - STEP[200]
# Generator_loss:2.0832
# L1_loss:0.2518
# Discriminator_loss:0.4491
#
# EPOCH[5] - STEP[210]
# Generator_loss:1.9147
# L1_loss:0.1927
# Discriminator_loss:0.4559
#
# EPOCH[5] - STEP[220]
# Generator_loss:1.0595
# L1_loss:0.1832
# Discriminator_loss:1.0274
#
# EPOCH[5] - STEP[230]
# Generator_loss:2.0425
# L1_loss:0.2065
# Discriminator_loss:0.6458
#
# EPOCH[5] - STEP[240]
# Generator_loss:0.3780
# L1_loss:0.2235
# Discriminator_loss:1.4591
#
# EPOCH[5] - STEP[250]
# Generator_loss:1.0200
# L1_loss:0.1661
# Discriminator_loss:1.0007
#
# EPOCH[6] - STEP[10]
# Generator_loss:1.8013
# L1_loss:0.2174
# Discriminator_loss:0.6542
#
# EPOCH[6] - STEP[20]
# Generator_loss:2.1705
# L1_loss:0.1935
# Discriminator_loss:0.6929
#
# EPOCH[6] - STEP[30]
# Generator_loss:0.4910
# L1_loss:0.1950
# Discriminator_loss:1.5042
#
# EPOCH[6] - STEP[40]
# Generator_loss:0.4249
# L1_loss:0.2085
# Discriminator_loss:1.3317
#
# EPOCH[6] - STEP[50]
# Generator_loss:2.7049
# L1_loss:0.2043
# Discriminator_loss:1.9784
#
# EPOCH[6] - STEP[60]
# Generator_loss:1.6903
# L1_loss:0.2018
# Discriminator_loss:0.5691
#
# EPOCH[6] - STEP[70]
# Generator_loss:0.2858
# L1_loss:0.1878
# Discriminator_loss:1.9921
#
# EPOCH[6] - STEP[80]
# Generator_loss:1.7799
# L1_loss:0.1571
# Discriminator_loss:0.9015
#
# EPOCH[6] - STEP[90]
# Generator_loss:1.7428
# L1_loss:0.2051
# Discriminator_loss:0.3370
#
# EPOCH[6] - STEP[100]
# Generator_loss:1.2669
# L1_loss:0.1672
# Discriminator_loss:0.4990
#
# EPOCH[6] - STEP[110]
# Generator_loss:1.3559
# L1_loss:0.1956
# Discriminator_loss:0.7336
#
# EPOCH[6] - STEP[120]
# Generator_loss:1.5316
# L1_loss:0.1995
# Discriminator_loss:0.4936
#
# EPOCH[6] - STEP[130]
# Generator_loss:1.3517
# L1_loss:0.2646
# Discriminator_loss:0.5236
#
# EPOCH[6] - STEP[140]
# Generator_loss:1.6508
# L1_loss:0.1938
# Discriminator_loss:0.7206
#
# EPOCH[6] - STEP[150]
# Generator_loss:2.3794
# L1_loss:0.1850
# Discriminator_loss:0.7088
#
# EPOCH[6] - STEP[160]
# Generator_loss:2.0871
# L1_loss:0.1753
# Discriminator_loss:1.2712
#
# EPOCH[6] - STEP[170]
# Generator_loss:1.5669
# L1_loss:0.1614
# Discriminator_loss:0.5855
#
# EPOCH[6] - STEP[180]
# Generator_loss:1.9200
# L1_loss:0.1811
# Discriminator_loss:0.8547
#
# EPOCH[6] - STEP[190]
# Generator_loss:2.0596
# L1_loss:0.1803
# Discriminator_loss:0.8403
#
# EPOCH[6] - STEP[200]
# Generator_loss:1.8269
# L1_loss:0.1951
# Discriminator_loss:0.9441
#
# EPOCH[6] - STEP[210]
# Generator_loss:1.9995
# L1_loss:0.1720
# Discriminator_loss:1.0561
#
# EPOCH[6] - STEP[220]
# Generator_loss:0.5169
# L1_loss:0.1911
# Discriminator_loss:1.3290
#
# EPOCH[6] - STEP[230]
# Generator_loss:0.5101
# L1_loss:0.1348
# Discriminator_loss:1.5580
#
# EPOCH[6] - STEP[240]
# Generator_loss:3.4674
# L1_loss:0.1935
# Discriminator_loss:0.7586
#
# EPOCH[6] - STEP[250]
# Generator_loss:2.5296
# L1_loss:0.2062
# Discriminator_loss:0.4109
#
# EPOCH[7] - STEP[10]
# Generator_loss:0.7678
# L1_loss:0.1867
# Discriminator_loss:0.8688
#
# EPOCH[7] - STEP[20]
# Generator_loss:1.6997
# L1_loss:0.1771
# Discriminator_loss:0.9144
#
# EPOCH[7] - STEP[30]
# Generator_loss:2.1450
# L1_loss:0.2008
# Discriminator_loss:0.2746
#
# EPOCH[7] - STEP[40]
# Generator_loss:1.9833
# L1_loss:0.1659
# Discriminator_loss:0.5960
#
# EPOCH[7] - STEP[50]
# Generator_loss:2.1722
# L1_loss:0.1840
# Discriminator_loss:0.5703
#
# EPOCH[7] - STEP[60]
# Generator_loss:0.2393
# L1_loss:0.2169
# Discriminator_loss:1.8418
#
# EPOCH[7] - STEP[70]
# Generator_loss:1.7871
# L1_loss:0.1789
# Discriminator_loss:0.9078
#
# EPOCH[7] - STEP[80]
# Generator_loss:1.3518
# L1_loss:0.1978
# Discriminator_loss:0.9028
#
# EPOCH[7] - STEP[90]
# Generator_loss:2.8349
# L1_loss:0.1849
# Discriminator_loss:0.5413
#
# EPOCH[7] - STEP[100]
# Generator_loss:2.8049
# L1_loss:0.1892
# Discriminator_loss:0.5772
#
# EPOCH[7] - STEP[110]
# Generator_loss:2.2761
# L1_loss:0.1675
# Discriminator_loss:1.9445
#
# EPOCH[7] - STEP[120]
# Generator_loss:1.3968
# L1_loss:0.1465
# Discriminator_loss:1.0149
#
# EPOCH[7] - STEP[130]
# Generator_loss:2.3162
# L1_loss:0.1955
# Discriminator_loss:1.0478
#
# EPOCH[7] - STEP[140]
# Generator_loss:1.9487
# L1_loss:0.1932
# Discriminator_loss:0.4766
#
# EPOCH[7] - STEP[150]
# Generator_loss:1.5183
# L1_loss:0.1613
# Discriminator_loss:0.7287
#
# EPOCH[7] - STEP[160]
# Generator_loss:1.8407
# L1_loss:0.1910
# Discriminator_loss:0.2936
#
# EPOCH[7] - STEP[170]
# Generator_loss:1.8876
# L1_loss:0.1612
# Discriminator_loss:0.6268
#
# EPOCH[7] - STEP[180]
# Generator_loss:1.7515
# L1_loss:0.1773
# Discriminator_loss:0.5064
# EPOCH[7] - STEP[190]
# Generator_loss:2.5280
# L1_loss:0.1628
# Discriminator_loss:0.3495
#
# EPOCH[7] - STEP[200]
# Generator_loss:1.2479
# L1_loss:0.1884
# Discriminator_loss:0.6830
#
# EPOCH[7] - STEP[210]
# Generator_loss:2.2165
# L1_loss:0.1962
# Discriminator_loss:0.6732
#
# EPOCH[7] - STEP[220]
# Generator_loss:1.4132
# L1_loss:0.1634
# Discriminator_loss:0.6175
#
# EPOCH[7] - STEP[230]
# Generator_loss:0.3715
# L1_loss:0.1645
# Discriminator_loss:1.8124
#
# EPOCH[7] - STEP[240]
# Generator_loss:2.1617
# L1_loss:0.1959
# Discriminator_loss:0.6202
#
# EPOCH[7] - STEP[250]
# Generator_loss:0.8872
# L1_loss:0.1749
# Discriminator_loss:1.3926
#
# EPOCH[8] - STEP[10]
# Generator_loss:2.2757
# L1_loss:0.1962
# Discriminator_loss:0.4898
#
# EPOCH[8] - STEP[20]
# Generator_loss:1.6814
# L1_loss:0.1879
# Discriminator_loss:0.4152
#
# EPOCH[8] - STEP[30]
# Generator_loss:1.7543
# L1_loss:0.1700
# Discriminator_loss:0.7063
#
# EPOCH[8] - STEP[40]
# Generator_loss:2.9442
# L1_loss:0.1816
# Discriminator_loss:0.1648
#
# EPOCH[8] - STEP[50]
# Generator_loss:2.3386
# L1_loss:0.1585
# Discriminator_loss:1.1086
#
# EPOCH[8] - STEP[60]
# Generator_loss:1.2541
# L1_loss:0.1592
# Discriminator_loss:0.9909
#
# EPOCH[8] - STEP[70]
# Generator_loss:1.0002
# L1_loss:0.1455
# Discriminator_loss:0.7987
#
# EPOCH[8] - STEP[80]
# Generator_loss:1.2379
# L1_loss:0.1796
# Discriminator_loss:0.8305
#
# EPOCH[8] - STEP[90]
# Generator_loss:0.2910
# L1_loss:0.2321
# Discriminator_loss:2.0022
#
# EPOCH[8] - STEP[100]
# Generator_loss:0.6703
# L1_loss:0.1937
# Discriminator_loss:1.1263
#
# EPOCH[8] - STEP[110]
# Generator_loss:0.9897
# L1_loss:0.1819
# Discriminator_loss:0.9878
#
# EPOCH[8] - STEP[120]
# Generator_loss:3.0425
# L1_loss:0.2106
# Discriminator_loss:0.2056
#
# EPOCH[8] - STEP[130]
# Generator_loss:1.1123
# L1_loss:0.1734
# Discriminator_loss:1.4601
#
# EPOCH[8] - STEP[140]
# Generator_loss:1.8950
# L1_loss:0.1749
# Discriminator_loss:0.3710
#
# EPOCH[8] - STEP[150]
# Generator_loss:0.5289
# L1_loss:0.1655
# Discriminator_loss:1.3494
#
# EPOCH[8] - STEP[160]
# Generator_loss:1.6987
# L1_loss:0.1779
# Discriminator_loss:0.6912
#
# EPOCH[8] - STEP[170]
# Generator_loss:1.7126
# L1_loss:0.1953
# Discriminator_loss:1.0150
#
# EPOCH[8] - STEP[180]
# Generator_loss:2.4307
# L1_loss:0.1756
# Discriminator_loss:0.6125
#
# EPOCH[8] - STEP[190]
# Generator_loss:1.7493
# L1_loss:0.1772
# Discriminator_loss:1.0698
#
# EPOCH[8] - STEP[200]
# Generator_loss:1.2676
# L1_loss:0.1739
# Discriminator_loss:0.5864
#
# EPOCH[8] - STEP[210]
# Generator_loss:2.2622
# L1_loss:0.1796
# Discriminator_loss:0.5322
#
# EPOCH[8] - STEP[220]
# Generator_loss:1.4555
# L1_loss:0.1725
# Discriminator_loss:0.8150
#
# EPOCH[8] - STEP[230]
# Generator_loss:1.3637
# L1_loss:0.1347
# Discriminator_loss:1.2134
#
# EPOCH[8] - STEP[240]
# Generator_loss:2.8298
# L1_loss:0.1930
# Discriminator_loss:0.9570
#
# EPOCH[8] - STEP[250]
# Generator_loss:2.1605
# L1_loss:0.1584
# Discriminator_loss:0.9274
#
# EPOCH[9] - STEP[10]
# Generator_loss:0.6122
# L1_loss:0.2077
# Discriminator_loss:1.1974
#
# EPOCH[9] - STEP[20]
# Generator_loss:2.5445
# L1_loss:0.2000
# Discriminator_loss:0.4053
#
# EPOCH[9] - STEP[30]
# Generator_loss:1.8093
# L1_loss:0.1802
# Discriminator_loss:0.7824
#
# EPOCH[9] - STEP[40]
# Generator_loss:1.3957
# L1_loss:0.1596
# Discriminator_loss:0.6381
#
# EPOCH[9] - STEP[50]
# Generator_loss:0.3101
# L1_loss:0.2393
# Discriminator_loss:1.6511
#
# EPOCH[9] - STEP[60]
# Generator_loss:0.8061
# L1_loss:0.1836
# Discriminator_loss:0.7531
#
# EPOCH[9] - STEP[70]
# Generator_loss:0.8327
# L1_loss:0.2538
# Discriminator_loss:1.2132
#
# EPOCH[9] - STEP[80]
# Generator_loss:1.4595
# L1_loss:0.1765
# Discriminator_loss:0.6981
#
# EPOCH[9] - STEP[90]
# Generator_loss:1.4508
# L1_loss:0.2234
# Discriminator_loss:0.5464
#
# EPOCH[9] - STEP[100]
# Generator_loss:3.1212
# L1_loss:0.2541
# Discriminator_loss:0.1531
#
# EPOCH[9] - STEP[110]
# Generator_loss:2.9304
# L1_loss:0.1638
# Discriminator_loss:0.7116
#
# EPOCH[9] - STEP[120]
# Generator_loss:0.6259
# L1_loss:0.1739
# Discriminator_loss:1.6492
#
# EPOCH[9] - STEP[130]
# Generator_loss:3.3650
# L1_loss:0.1813
# Discriminator_loss:0.9421
#
# EPOCH[9] - STEP[140]
# Generator_loss:0.1069
# L1_loss:0.1703
# Discriminator_loss:2.6829
#
# EPOCH[9] - STEP[150]
# Generator_loss:0.5943
# L1_loss:0.1575
# Discriminator_loss:1.2740
#
# EPOCH[9] - STEP[160]
# Generator_loss:1.9228
# L1_loss:0.1376
# Discriminator_loss:0.9365
#
# EPOCH[9] - STEP[170]
# Generator_loss:2.2544
# L1_loss:0.2093
# Discriminator_loss:0.4758
#
# EPOCH[9] - STEP[180]
# Generator_loss:0.7618
# L1_loss:0.1913
# Discriminator_loss:1.1236
#
# EPOCH[9] - STEP[190]
# Generator_loss:2.7519
# L1_loss:0.1466
# Discriminator_loss:1.1347
#
# EPOCH[9] - STEP[200]
# Generator_loss:1.3109
# L1_loss:0.1640
# Discriminator_loss:0.5552
#
# EPOCH[9] - STEP[210]
# Generator_loss:2.4928
# L1_loss:0.1517
# Discriminator_loss:2.5504
#
# EPOCH[9] - STEP[220]
# Generator_loss:1.0275
# L1_loss:0.1580
# Discriminator_loss:0.9027
#
# EPOCH[9] - STEP[230]
# Generator_loss:1.8525
# L1_loss:0.1573
# Discriminator_loss:1.1768
#
# EPOCH[9] - STEP[240]
# Generator_loss:0.9340
# L1_loss:0.1818
# Discriminator_loss:1.0696
# EPOCH[9] - STEP[250]
# Generator_loss:1.7407
# L1_loss:0.2008
# Discriminator_loss:0.4389
#
# EPOCH[10] - STEP[10]
# Generator_loss:1.1268
# L1_loss:0.1848
# Discriminator_loss:0.5934
#
# EPOCH[10] - STEP[20]
# Generator_loss:2.7772
# L1_loss:0.1765
# Discriminator_loss:1.0661
#
# EPOCH[10] - STEP[30]
# Generator_loss:0.6521
# L1_loss:0.1870
# Discriminator_loss:1.0246
#
# EPOCH[10] - STEP[40]
# Generator_loss:1.3611
# L1_loss:0.2345
# Discriminator_loss:0.5398
#
# EPOCH[10] - STEP[50]
# Generator_loss:1.6640
# L1_loss:0.2016
# Discriminator_loss:0.8157
#
# EPOCH[10] - STEP[60]
# Generator_loss:1.1563
# L1_loss:0.1489
# Discriminator_loss:0.6815
#
# EPOCH[10] - STEP[70]
# Generator_loss:1.3294
# L1_loss:0.1856
# Discriminator_loss:0.5137
#
# EPOCH[10] - STEP[80]
# Generator_loss:1.4032
# L1_loss:0.1360
# Discriminator_loss:0.9160
#
# EPOCH[10] - STEP[90]
# Generator_loss:1.5269
# L1_loss:0.1789
# Discriminator_loss:0.3643
#
# EPOCH[10] - STEP[100]
# Generator_loss:2.1845
# L1_loss:0.1857
# Discriminator_loss:0.4844
#
# EPOCH[10] - STEP[110]
# Generator_loss:1.8047
# L1_loss:0.2094
# Discriminator_loss:0.4257
#
# EPOCH[10] - STEP[120]
# Generator_loss:2.0398
# L1_loss:0.1548
# Discriminator_loss:0.5786
#
# EPOCH[10] - STEP[130]
# Generator_loss:3.1345
# L1_loss:0.2280
# Discriminator_loss:0.3364
#
# EPOCH[10] - STEP[140]
# Generator_loss:2.5561
# L1_loss:0.1861
# Discriminator_loss:0.3777
#
# EPOCH[10] - STEP[150]
# Generator_loss:1.0783
# L1_loss:0.1867
# Discriminator_loss:0.7535
#
# EPOCH[10] - STEP[160]
# Generator_loss:1.6309
# L1_loss:0.1741
# Discriminator_loss:0.4358
#
# EPOCH[10] - STEP[170]
# Generator_loss:2.4519
# L1_loss:0.2080
# Discriminator_loss:0.5024
#
# EPOCH[10] - STEP[180]
# Generator_loss:2.1895
# L1_loss:0.2211
# Discriminator_loss:0.6503
#
# EPOCH[10] - STEP[190]
# Generator_loss:1.4649
# L1_loss:0.1685
# Discriminator_loss:0.6062
#
# EPOCH[10] - STEP[200]
# Generator_loss:1.9999
# L1_loss:0.1923
# Discriminator_loss:0.4615
#
# EPOCH[10] - STEP[210]
# Generator_loss:2.6869
# L1_loss:0.1410
# Discriminator_loss:1.9468
#
# EPOCH[10] - STEP[220]
# Generator_loss:2.8033
# L1_loss:0.1713
# Discriminator_loss:1.3442
#
# EPOCH[10] - STEP[230]
# Generator_loss:2.0747
# L1_loss:0.1546
# Discriminator_loss:0.6127
#
# EPOCH[10] - STEP[240]
# Generator_loss:1.3065
# L1_loss:0.2003
# Discriminator_loss:0.4891
#
# EPOCH[10] - STEP[250]
# Generator_loss:1.3429
# L1_loss:0.1916
# Discriminator_loss:0.4213
#
# EPOCH[11] - STEP[10]
# Generator_loss:1.6028
# L1_loss:0.2313
# Discriminator_loss:0.4324
#
# EPOCH[11] - STEP[20]
# Generator_loss:0.9004
# L1_loss:0.1677
# Discriminator_loss:0.7285
#
# EPOCH[11] - STEP[30]
# Generator_loss:3.2617
# L1_loss:0.1490
# Discriminator_loss:0.2007
#
# EPOCH[11] - STEP[40]
# Generator_loss:1.3377
# L1_loss:0.1618
# Discriminator_loss:0.5802
#
# EPOCH[11] - STEP[50]
# Generator_loss:2.5965
# L1_loss:0.1367
# Discriminator_loss:0.6275
#
# EPOCH[11] - STEP[60]
# Generator_loss:2.5659
# L1_loss:0.1341
# Discriminator_loss:1.4338
#
# EPOCH[11] - STEP[70]
# Generator_loss:1.7392
# L1_loss:0.1689
# Discriminator_loss:0.3267
#
# EPOCH[11] - STEP[80]
# Generator_loss:1.0736
# L1_loss:0.1702
# Discriminator_loss:0.8630
#
# EPOCH[11] - STEP[90]
# Generator_loss:2.3319
# L1_loss:0.1561
# Discriminator_loss:0.7056
#
# EPOCH[11] - STEP[100]
# Generator_loss:2.2323
# L1_loss:0.1781
# Discriminator_loss:0.2782
#
# EPOCH[11] - STEP[110]
# Generator_loss:2.4680
# L1_loss:0.1674
# Discriminator_loss:1.2076
#
# EPOCH[11] - STEP[120]
# Generator_loss:1.7615
# L1_loss:0.2745
# Discriminator_loss:0.4510
#
# EPOCH[11] - STEP[130]
# Generator_loss:1.1073
# L1_loss:0.1417
# Discriminator_loss:1.1440
#
# EPOCH[11] - STEP[140]
# Generator_loss:0.9423
# L1_loss:0.1775
# Discriminator_loss:0.7515
#
# EPOCH[11] - STEP[150]
# Generator_loss:1.0781
# L1_loss:0.1771
# Discriminator_loss:0.6789
#
# EPOCH[11] - STEP[160]
# Generator_loss:0.8663
# L1_loss:0.1784
# Discriminator_loss:1.0672
#
# EPOCH[11] - STEP[170]
# Generator_loss:0.7906
# L1_loss:0.2310
# Discriminator_loss:0.9118
#
# EPOCH[11] - STEP[180]
# Generator_loss:2.8192
# L1_loss:0.1642
# Discriminator_loss:0.9500
#
# EPOCH[11] - STEP[190]
# Generator_loss:1.3731
# L1_loss:0.1488
# Discriminator_loss:0.6947
#
# EPOCH[11] - STEP[200]
# Generator_loss:2.6526
# L1_loss:0.1542
# Discriminator_loss:1.4046
#
# EPOCH[11] - STEP[210]
# Generator_loss:1.1695
# L1_loss:0.2181
# Discriminator_loss:0.6600
#
# EPOCH[11] - STEP[220]
# Generator_loss:1.3718
# L1_loss:0.2117
# Discriminator_loss:0.6397
#
# EPOCH[11] - STEP[230]
# Generator_loss:2.5111
# L1_loss:0.1571
# Discriminator_loss:0.2405
#
# EPOCH[11] - STEP[240]
# Generator_loss:2.9040
# L1_loss:0.1520
# Discriminator_loss:0.8931
#
# EPOCH[11] - STEP[250]
# Generator_loss:0.6143
# L1_loss:0.2267
# Discriminator_loss:1.2617
#
# EPOCH[12] - STEP[10]
# Generator_loss:0.4174
# L1_loss:0.1963
# Discriminator_loss:1.4668
#
# EPOCH[12] - STEP[20]
# Generator_loss:2.0667
# L1_loss:0.1863
# Discriminator_loss:0.5098
#
# EPOCH[12] - STEP[30]
# Generator_loss:1.7444
# L1_loss:0.1550
# Discriminator_loss:1.1477
#
# EPOCH[12] - STEP[40]
# Generator_loss:2.8807
# L1_loss:0.1753
# Discriminator_loss:0.4042
#
# EPOCH[12] - STEP[50]
# Generator_loss:2.2148
# L1_loss:0.1710
# Discriminator_loss:0.4049
# EPOCH[12] - STEP[60]
# Generator_loss:0.7638
# L1_loss:0.1616
# Discriminator_loss:1.5415
#
# EPOCH[12] - STEP[70]
# Generator_loss:1.9587
# L1_loss:0.1780
# Discriminator_loss:0.3305
#
# EPOCH[12] - STEP[80]
# Generator_loss:1.7840
# L1_loss:0.1745
# Discriminator_loss:0.5056
#
# EPOCH[12] - STEP[90]
# Generator_loss:1.4091
# L1_loss:0.2014
# Discriminator_loss:1.9835
#
# EPOCH[12] - STEP[100]
# Generator_loss:3.1944
# L1_loss:0.1838
# Discriminator_loss:0.9339
#
# EPOCH[12] - STEP[110]
# Generator_loss:2.0223
# L1_loss:0.1656
# Discriminator_loss:0.5909
#
# EPOCH[12] - STEP[120]
# Generator_loss:3.4678
# L1_loss:0.1623
# Discriminator_loss:1.4244
#
# EPOCH[12] - STEP[130]
# Generator_loss:2.7666
# L1_loss:0.1733
# Discriminator_loss:0.3249
#
# EPOCH[12] - STEP[140]
# Generator_loss:3.2549
# L1_loss:0.1763
# Discriminator_loss:0.2630
#
# EPOCH[12] - STEP[150]
# Generator_loss:0.5792
# L1_loss:0.1799
# Discriminator_loss:1.0624
#
# EPOCH[12] - STEP[160]
# Generator_loss:0.4944
# L1_loss:0.1819
# Discriminator_loss:1.2917
#
# EPOCH[12] - STEP[170]
# Generator_loss:1.0131
# L1_loss:0.1769
# Discriminator_loss:0.9325
#
# EPOCH[12] - STEP[180]
# Generator_loss:0.8070
# L1_loss:0.1812
# Discriminator_loss:0.9408
#
# EPOCH[12] - STEP[190]
# Generator_loss:3.2917
# L1_loss:0.1583
# Discriminator_loss:0.3687
#
# EPOCH[12] - STEP[200]
# Generator_loss:1.6427
# L1_loss:0.1992
# Discriminator_loss:0.6649
#
# EPOCH[12] - STEP[210]
# Generator_loss:1.8451
# L1_loss:0.1628
# Discriminator_loss:1.1375
#
# EPOCH[12] - STEP[220]
# Generator_loss:2.0153
# L1_loss:0.1619
# Discriminator_loss:0.3961
#
# EPOCH[12] - STEP[230]
# Generator_loss:1.7579
# L1_loss:0.1731
# Discriminator_loss:0.4191
#
# EPOCH[12] - STEP[240]
# Generator_loss:3.1570
# L1_loss:0.1466
# Discriminator_loss:1.2664
#
# EPOCH[12] - STEP[250]
# Generator_loss:2.1721
# L1_loss:0.1366
# Discriminator_loss:1.0440
#
# EPOCH[13] - STEP[10]
# Generator_loss:1.4699
# L1_loss:0.1851
# Discriminator_loss:0.4243
#
# EPOCH[13] - STEP[20]
# Generator_loss:1.8342
# L1_loss:0.1651
# Discriminator_loss:1.2393
#
# EPOCH[13] - STEP[30]
# Generator_loss:2.9511
# L1_loss:0.1501
# Discriminator_loss:0.4552
#
# EPOCH[13] - STEP[40]
# Generator_loss:0.9255
# L1_loss:0.1565
# Discriminator_loss:0.7967
#
# EPOCH[13] - STEP[50]
# Generator_loss:1.2718
# L1_loss:0.1566
# Discriminator_loss:0.5031
#
# EPOCH[13] - STEP[60]
# Generator_loss:1.1415
# L1_loss:0.1710
# Discriminator_loss:0.7439
#
# EPOCH[13] - STEP[70]
# Generator_loss:1.4094
# L1_loss:0.1727
# Discriminator_loss:0.7572
#
# EPOCH[13] - STEP[80]
# Generator_loss:1.0325
# L1_loss:0.1862
# Discriminator_loss:0.6604
#
# EPOCH[13] - STEP[90]
# Generator_loss:0.3306
# L1_loss:0.1671
# Discriminator_loss:1.8370
#
# EPOCH[13] - STEP[100]
# Generator_loss:1.6208
# L1_loss:0.1805
# Discriminator_loss:0.4104
#
# EPOCH[13] - STEP[110]
# Generator_loss:1.3275
# L1_loss:0.1728
# Discriminator_loss:0.4275
#
# EPOCH[13] - STEP[120]
# Generator_loss:0.3873
# L1_loss:0.1738
# Discriminator_loss:1.6390
#
# EPOCH[13] - STEP[130]
# Generator_loss:1.7027
# L1_loss:0.1501
# Discriminator_loss:0.9113
#
# EPOCH[13] - STEP[140]
# Generator_loss:0.9905
# L1_loss:0.1708
# Discriminator_loss:0.6747
#
# EPOCH[13] - STEP[150]
# Generator_loss:1.5668
# L1_loss:0.1818
# Discriminator_loss:0.4750
#
# EPOCH[13] - STEP[160]
# Generator_loss:0.9770
# L1_loss:0.1560
# Discriminator_loss:2.1355
#
# EPOCH[13] - STEP[170]
# Generator_loss:2.1850
# L1_loss:0.1345
# Discriminator_loss:0.5286
#
# EPOCH[13] - STEP[180]
# Generator_loss:2.6391
# L1_loss:0.1490
# Discriminator_loss:0.6192
#
# EPOCH[13] - STEP[190]
# Generator_loss:1.7556
# L1_loss:0.1716
# Discriminator_loss:0.5366
#
# EPOCH[13] - STEP[200]
# Generator_loss:1.8267
# L1_loss:0.1889
# Discriminator_loss:0.3388
#
# EPOCH[13] - STEP[210]
# Generator_loss:3.9373
# L1_loss:0.1324
# Discriminator_loss:3.1700
#
# EPOCH[13] - STEP[220]
# Generator_loss:3.3858
# L1_loss:0.1764
# Discriminator_loss:0.5045
#
# EPOCH[13] - STEP[230]
# Generator_loss:1.2582
# L1_loss:0.1474
# Discriminator_loss:0.7273
#
# EPOCH[13] - STEP[240]
# Generator_loss:2.1281
# L1_loss:0.1501
# Discriminator_loss:0.6572
#
# EPOCH[13] - STEP[250]
# ...
# L1_loss:0.1635
# Discriminator_loss:0.3685
#
# EPOCH[16] - STEP[190]
# Generator_loss:2.7607
# L1_loss:0.2100
# Discriminator_loss:0.2214
#
# EPOCH[16] - STEP[200]
# Generator_loss:1.7793
# L1_loss:0.1866
# Discriminator_loss:0.5524
#
# EPOCH[16] - STEP[210]
# Generator_loss:2.2382
# L1_loss:0.1631
# Discriminator_loss:0.7791
#
# EPOCH[16] - STEP[220]
# Generator_loss:3.4662
# L1_loss:0.1707
# Discriminator_loss:1.0487
#
# EPOCH[16] - STEP[230]
# Generator_loss:3.0985
# L1_loss:0.2168
# Discriminator_loss:0.1708
#
# EPOCH[16] - STEP[240]
# Generator_loss:1.4996
# L1_loss:0.1514
# Discriminator_loss:0.5486
#
# EPOCH[16] - STEP[250]
# Generator_loss:2.8794
# L1_loss:0.1193
# Discriminator_loss:0.4939
#
# EPOCH[17] - STEP[10]
# Generator_loss:1.2266
# L1_loss:0.1559
# Discriminator_loss:0.9151
#
# EPOCH[17] - STEP[20]
# Generator_loss:0.1799
# L1_loss:0.1486
# Discriminator_loss:2.4230
#
# EPOCH[17] - STEP[30]
# Generator_loss:1.6985
# L1_loss:0.2556
# Discriminator_loss:0.4170
#
# EPOCH[17] - STEP[40]
# Generator_loss:1.9633
# L1_loss:0.1374
# Discriminator_loss:0.5158
#
# EPOCH[17] - STEP[50]
# Generator_loss:1.5948
# L1_loss:0.1984
# Discriminator_loss:0.4360
#
# EPOCH[17] - STEP[60]
# Generator_loss:1.8431
# L1_loss:0.1792
# Discriminator_loss:0.6069
#
# EPOCH[17] - STEP[70]
# Generator_loss:2.7436
# L1_loss:0.1612
# Discriminator_loss:0.7725
#
# EPOCH[17] - STEP[80]
# Generator_loss:2.8097
# L1_loss:0.1781
# Discriminator_loss:0.5999
#
# EPOCH[17] - STEP[90]
# Generator_loss:1.4446
# L1_loss:0.1718
# Discriminator_loss:0.4991
#
# EPOCH[17] - STEP[100]
# Generator_loss:3.1389
# L1_loss:0.1867
# Discriminator_loss:0.7283
#
# EPOCH[17] - STEP[110]
# Generator_loss:1.2468
# L1_loss:0.1954
# Discriminator_loss:0.4753
#
# EPOCH[17] - STEP[120]
# Generator_loss:2.3147
# L1_loss:0.1514
# Discriminator_loss:0.8401
#
# EPOCH[17] - STEP[130]
# Generator_loss:1.9798
# L1_loss:0.1522
# Discriminator_loss:0.5282
#
# EPOCH[17] - STEP[140]
# Generator_loss:1.4989
# L1_loss:0.1883
# Discriminator_loss:0.5635
#
# EPOCH[17] - STEP[150]
# Generator_loss:2.4417
# L1_loss:0.1802
# Discriminator_loss:1.2352
#
# EPOCH[17] - STEP[160]
# Generator_loss:0.9542
# L1_loss:0.1599
# Discriminator_loss:0.7927
#
# EPOCH[17] - STEP[170]
# Generator_loss:2.2352
# L1_loss:0.1687
# Discriminator_loss:0.8552
#
# EPOCH[17] - STEP[180]
# Generator_loss:1.5418
# L1_loss:0.1163
# Discriminator_loss:0.8039
#
# EPOCH[17] - STEP[190]
# Generator_loss:0.9260
# L1_loss:0.1683
# Discriminator_loss:1.4387
#
# EPOCH[17] - STEP[200]
# Generator_loss:2.0227
# L1_loss:0.2248
# Discriminator_loss:0.2966
#
# EPOCH[17] - STEP[210]
# Generator_loss:2.3131
# L1_loss:0.1479
# Discriminator_loss:0.4167
#
# EPOCH[17] - STEP[220]
# Generator_loss:2.8858
# L1_loss:0.1310
# Discriminator_loss:0.7500
#
# EPOCH[17] - STEP[230]
# Generator_loss:0.7060
# L1_loss:0.1813
# Discriminator_loss:0.9149
#
# EPOCH[17] - STEP[240]
# Generator_loss:3.3112
# L1_loss:0.1906
# Discriminator_loss:0.6700
#
# EPOCH[17] - STEP[250]
# Generator_loss:3.6832
# L1_loss:0.1902
# Discriminator_loss:0.6762
#
# EPOCH[18] - STEP[10]
# Generator_loss:1.0624
# L1_loss:0.1607
# Discriminator_loss:0.7041
#
# EPOCH[18] - STEP[20]
# Generator_loss:2.4959
# L1_loss:0.1359
# Discriminator_loss:1.1237
#
# EPOCH[18] - STEP[30]
# Generator_loss:0.8427
# L1_loss:0.1957
# Discriminator_loss:0.8247
#
# EPOCH[18] - STEP[40]
# Generator_loss:1.3460
# L1_loss:0.1761
# Discriminator_loss:0.6301
#
# EPOCH[18] - STEP[50]
# Generator_loss:2.8525
# L1_loss:0.1615
# Discriminator_loss:0.1476
#
# EPOCH[18] - STEP[60]
# Generator_loss:2.5145
# L1_loss:0.1487
# Discriminator_loss:0.8355
#
# EPOCH[18] - STEP[70]
# Generator_loss:3.1403
# L1_loss:0.1777
# Discriminator_loss:0.4375
#
# EPOCH[18] - STEP[80]
# Generator_loss:2.6742
# L1_loss:0.1861
# Discriminator_loss:0.8159
#
# EPOCH[18] - STEP[90]
# Generator_loss:2.0085
# L1_loss:0.1660
# Discriminator_loss:0.3830
#
# EPOCH[18] - STEP[100]
# Generator_loss:2.9664
# L1_loss:0.1694
# Discriminator_loss:0.4016
#
# EPOCH[18] - STEP[110]
# Generator_loss:2.0116
# L1_loss:0.1406
# Discriminator_loss:0.4002
#
# EPOCH[18] - STEP[120]
# Generator_loss:0.6009
# L1_loss:0.2174
# Discriminator_loss:1.2683
#
# EPOCH[18] - STEP[130]
# Generator_loss:1.6867
# L1_loss:0.1850
# Discriminator_loss:0.5040
#
# EPOCH[18] - STEP[140]
# Generator_loss:0.7683
# L1_loss:0.1673
# Discriminator_loss:0.8170
#
# EPOCH[18] - STEP[150]
# Generator_loss:0.7581
# L1_loss:0.2007
# Discriminator_loss:1.0923
#
# EPOCH[18] - STEP[160]
# Generator_loss:1.7769
# L1_loss:0.1659
# Discriminator_loss:0.6621
#
# EPOCH[18] - STEP[170]
# Generator_loss:2.1397
# L1_loss:0.1611
# Discriminator_loss:1.2014
#
# EPOCH[18] - STEP[180]
# Generator_loss:2.6440
# L1_loss:0.1695
# Discriminator_loss:0.9459
#
# EPOCH[18] - STEP[190]
# Generator_loss:0.6530
# L1_loss:0.1639
# Discriminator_loss:0.9940
#
# EPOCH[18] - STEP[200]
# Generator_loss:1.2742
# L1_loss:0.1690
# Discriminator_loss:0.5000
#
# EPOCH[18] - STEP[210]
# Generator_loss:2.3489
# L1_loss:0.1468
# Discriminator_loss:0.2498
#
# EPOCH[18] - STEP[220]
# Generator_loss:1.8033
# L1_loss:0.2060
# Discriminator_loss:0.6589
#
# EPOCH[18] - STEP[230]
# Generator_loss:1.7661
# L1_loss:0.1282
# Discriminator_loss:0.7461
# EPOCH[18] - STEP[240]
# Generator_loss:1.5950
# L1_loss:0.1571
# Discriminator_loss:0.4126
#
# EPOCH[18] - STEP[250]
# Generator_loss:2.5217
# L1_loss:0.1796
# Discriminator_loss:0.3945
#
# EPOCH[19] - STEP[10]
# Generator_loss:1.9995
# L1_loss:0.2019
# Discriminator_loss:0.2629
#
# EPOCH[19] - STEP[20]
# Generator_loss:1.3525
# L1_loss:0.1980
# Discriminator_loss:0.5497
#
# EPOCH[19] - STEP[30]
# Generator_loss:3.8564
# L1_loss:0.1368
# Discriminator_loss:0.5443
#
# EPOCH[19] - STEP[40]
# Generator_loss:2.4148
# L1_loss:0.1892
# Discriminator_loss:0.6051
#
# EPOCH[19] - STEP[50]
# Generator_loss:0.8423
# L1_loss:0.1760
# Discriminator_loss:0.9024
#
# EPOCH[19] - STEP[60]
# Generator_loss:1.8276
# L1_loss:0.1800
# Discriminator_loss:0.7830
#
# EPOCH[19] - STEP[70]
# Generator_loss:1.0291
# L1_loss:0.1916
# Discriminator_loss:0.6938
#
# EPOCH[19] - STEP[80]
# Generator_loss:0.4700
# L1_loss:0.1874
# Discriminator_loss:1.3351
#
# EPOCH[19] - STEP[90]
# Generator_loss:2.2613
# L1_loss:0.1884
# Discriminator_loss:0.2895
#
# EPOCH[19] - STEP[100]
# Generator_loss:2.0013
# L1_loss:0.2023
# Discriminator_loss:1.0916
#
# EPOCH[19] - STEP[110]
# Generator_loss:2.0866
# L1_loss:0.1431
# Discriminator_loss:0.3482
#
# EPOCH[19] - STEP[120]
# Generator_loss:2.8130
# L1_loss:0.1380
# Discriminator_loss:1.8419
#
# EPOCH[19] - STEP[130]
# Generator_loss:2.2455
# L1_loss:0.1782
# Discriminator_loss:0.5918
#
# EPOCH[19] - STEP[140]
# Generator_loss:1.4891
# L1_loss:0.1860
# Discriminator_loss:0.8139
#
# EPOCH[19] - STEP[150]
# Generator_loss:4.3412
# L1_loss:0.1665
# Discriminator_loss:1.2083
#
# EPOCH[19] - STEP[160]
# Generator_loss:4.1652
# L1_loss:0.1529
# Discriminator_loss:1.2433
#
# EPOCH[19] - STEP[170]
# Generator_loss:1.4598
# L1_loss:0.1604
# Discriminator_loss:0.4356
#
# EPOCH[19] - STEP[180]
# Generator_loss:1.7835
# L1_loss:0.1954
# Discriminator_loss:0.5902
#
# EPOCH[19] - STEP[190]
# Generator_loss:3.1886
# L1_loss:0.1641
# Discriminator_loss:0.8265
#
# EPOCH[19] - STEP[200]
# Generator_loss:0.8977
# L1_loss:0.1534
# Discriminator_loss:0.7692
#
# EPOCH[19] - STEP[210]
# Generator_loss:1.7172
# L1_loss:0.1243
# Discriminator_loss:0.5572
#
# EPOCH[19] - STEP[220]
# Generator_loss:1.3919
# L1_loss:0.1473
# Discriminator_loss:0.6585
#
# EPOCH[19] - STEP[230]
# Generator_loss:1.5424
# L1_loss:0.1744
# Discriminator_loss:0.4614
#
# EPOCH[19] - STEP[240]
# Generator_loss:1.4372
# L1_loss:0.1458
# Discriminator_loss:0.5939
#
# EPOCH[19] - STEP[250]
# Generator_loss:1.3209
# L1_loss:0.1486
# Discriminator_loss:0.7288
#
# EPOCH[20] - STEP[10]
# Generator_loss:2.0069
# L1_loss:0.1465
# Discriminator_loss:0.5522
#
# EPOCH[20] - STEP[20]
# Generator_loss:2.6712
# L1_loss:0.1270
# Discriminator_loss:1.4502
#
# EPOCH[20] - STEP[30]
# Generator_loss:2.1179
# L1_loss:0.1693
# Discriminator_loss:0.2977
#
# EPOCH[20] - STEP[40]
# Generator_loss:0.6345
# L1_loss:0.1410
# Discriminator_loss:1.0240
#
# EPOCH[20] - STEP[50]
# Generator_loss:2.8679
# L1_loss:0.1480
# Discriminator_loss:0.2845
#
# EPOCH[20] - STEP[60]
# Generator_loss:2.0676
# L1_loss:0.1859
# Discriminator_loss:0.2855
#
# EPOCH[20] - STEP[70]
# Generator_loss:2.2312
# L1_loss:0.1960
# Discriminator_loss:0.3223
#
# EPOCH[20] - STEP[80]
# Generator_loss:2.1957
# L1_loss:0.1933
# Discriminator_loss:0.4854
#
# EPOCH[20] - STEP[90]
# Generator_loss:0.2653
# L1_loss:0.1387
# Discriminator_loss:2.0748
#
# EPOCH[20] - STEP[100]
# Generator_loss:3.2466
# L1_loss:0.1904
# Discriminator_loss:0.8115
#
# EPOCH[20] - STEP[110]
# Generator_loss:2.3518
# L1_loss:0.1993
# Discriminator_loss:0.3563
#
# EPOCH[20] - STEP[120]
# Generator_loss:3.1884
# L1_loss:0.1617
# Discriminator_loss:0.5255
#
# EPOCH[20] - STEP[130]
# Generator_loss:1.9727
# L1_loss:0.1250
# Discriminator_loss:0.5082
#
# EPOCH[20] - STEP[140]
# Generator_loss:2.8797
# L1_loss:0.1606
# Discriminator_loss:0.2112
#
# EPOCH[20] - STEP[150]
# Generator_loss:2.1745
# L1_loss:0.1952
# Discriminator_loss:0.2584
#
# EPOCH[20] - STEP[160]
# Generator_loss:1.4114
# L1_loss:0.1931
# Discriminator_loss:0.4941
#
# EPOCH[20] - STEP[170]
# Generator_loss:4.0753
# L1_loss:0.1672
# Discriminator_loss:0.5165
#
# EPOCH[20] - STEP[180]
# Generator_loss:2.6744
# L1_loss:0.1472
# Discriminator_loss:0.6010
#
# EPOCH[20] - STEP[190]
# Generator_loss:2.5706
# L1_loss:0.2193
# Discriminator_loss:0.2576
#
# EPOCH[20] - STEP[200]
# Generator_loss:1.0034
# L1_loss:0.1522
# Discriminator_loss:0.7778
#
# EPOCH[20] - STEP[210]
# Generator_loss:3.5675
# L1_loss:0.1879
# Discriminator_loss:0.2926
#
# EPOCH[20] - STEP[220]
# Generator_loss:1.3557
# L1_loss:0.1680
# Discriminator_loss:0.5163
#
# EPOCH[20] - STEP[230]
# Generator_loss:1.5939
# L1_loss:0.1593
# Discriminator_loss:0.5006
#
# EPOCH[20] - STEP[240]
# Generator_loss:1.6138
# L1_loss:0.1513
# Discriminator_loss:0.6462
#
# EPOCH[20] - STEP[250]
# Generator_loss:1.8719
# L1_loss:0.1741
# Discriminator_loss:0.5279

# %%
test_ind = 1

test_data_path = './data/cityscapes/val/'

f = test_data_path + os.listdir(test_data_path)[test_ind]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))
